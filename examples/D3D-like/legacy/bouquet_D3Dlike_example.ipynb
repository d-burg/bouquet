# %% [markdown]
# # Bouquet + TokaMaker: DIII-D Equilibrium Reconstruction and Perturbation
#
# This notebook demonstrates the full **bouquet** workflow for producing
# families of perturbed tokamak equilibria from EFIT-format input files:
#
# 1. **Load inputs** — read g-files (magnetic equilibria) and p-files
#    (kinetic profiles) using the bouquet I/O modules.
# 2. **Reconstruct equilibria** — reproduce each g-file equilibrium in
#    TokaMaker via an inverse solve, decomposing the toroidal current
#    density into inductive ($j_{\text{ind}}$) and bootstrap
#    ($j_{\text{BS}}$) components.
# 3. **Verify reconstructions** — compare TokaMaker’s solution against
#    the original g-file using `plot_tokamaker_comparison()`.
# 4. **Generate perturbed families** — use Gaussian-process-regression
#    (GPR) sampling to produce statistically consistent variations of
#    the kinetic and current-density profiles, each iterated to match
#    $I_p$ and $l_i$.
# 5. **Visualize results** — inspect the perturbed families with
#    `plot_bouquet()`.
#
# ### Prerequisites
#
# | Package | Purpose |
# |---|---|
# | [OpenFUSIONToolkit / TokaMaker](https://github.com/OpenFUSIONToolkit) | Grad–Shafranov solver |
# | [h5py](https://www.h5py.org/) | HDF5 equilibrium database |
# | bouquet | This package — I/O, reconstruction, perturbation, plotting |
#
# ### Input files (in this directory)
#
# | File | Description |
# |---|---|
# | `TkMkr_D3Dlike_Hmode_BSamp=*.geqdsk` | TokaMaker-generated DIII-D–like H-mode equilibria |
# | `TkMkr_D3Dlike_Hmode_BSamp=*.peqdsk` | Corresponding kinetic profiles in Osborne p-file format |
# | `DIIID_mesh.h5` | Pre-built TokaMaker finite-element mesh for DIII-D |

# %% [markdown]
# ## 1. Imports

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# --- TokaMaker ---
tokamaker_python_path = '/Users/danielburgess/Desktop/plasma/OpenFUSIONToolkit/build_release'
if tokamaker_python_path is not None:
    sys.path.append(os.path.join(tokamaker_python_path, 'python'))

from OpenFUSIONToolkit import OFT_env
from OpenFUSIONToolkit.TokaMaker import TokaMaker
from OpenFUSIONToolkit.TokaMaker.meshing import load_gs_mesh
from OpenFUSIONToolkit.TokaMaker.util import create_power_flux_fun

# --- Bouquet ---
from bouquet import (
    read_geqdsk,
    reconstruct_equilibrium,
    generate_bouquet,
    initialize_equilibrium_database,
    store_equilibrium,
    calc_cylindrical_li_proxy,
    plot_tokamaker_comparison,
    plot_bouquet, plot_traces,
)
from bouquet.io.pfile import read_pfile
from bouquet import new_uncertainty_profiles
from bouquet import sigmoid_length_scale

# %% [markdown]
# ## 2. User configuration
#
# All tunable parameters are collected here so that the rest of the
# notebook can be run without modification.  Adjust these to your use
# case:
#
# - **`geqdsks` / `pfiles`**: matched lists of g-file and p-file paths.
# - **`frac_*`**: fractional 1-$\sigma$ uncertainties for GPR perturbation.
# - **`n_equils`**: number of perturbed equilibria per baseline.
# - **`*_ls`**: GPR correlation length scales (0–1 in $\psi_N$).

# %%
# ----- Input file lists (must be same length and in matching order) -----
geqdsks = [
    'TkMkr_D3Dlike_Hmode_BSamp=1.0.geqdsk',
    'TkMkr_D3Dlike_Hmode_BSamp=1.25.geqdsk',
]
pfiles = [
    'TkMkr_D3Dlike_Hmode_BSamp=1.0.peqdsk',
    'TkMkr_D3Dlike_Hmode_BSamp=1.25.peqdsk',
]

header = 'TkMkr_D3Dlike_Hmode'   # HDF5 database name (without .h5)

# ----- Uncertainty envelope parameters for GPR perturbation -----
# new_uncertainty_profiles(psi_N, frac, falloff_exp) generates a
# radially-varying fractional envelope:
#
#   sigma(psi_N) = (frac * (1 - psi_N)^falloff_exp + shelf) * profile(psi_N)
#
# Larger falloff_exp => tighter constraint near the pedestal/edge
# (where Thomson scattering is better constrained) and wider in the core.
frac_ne   = 0.20;  falloff_ne   = 0.5   # electron density
frac_te   = 0.20;  falloff_te   = 0.5   # electron temperature
frac_ni   = 0.30;  falloff_ni   = 0.3    # ion density
frac_ti   = 0.30;  falloff_ti   = 0.3    # ion temperature
frac_jphi = 0.15;                        # toroidal current density, using a flat envelope instead
shelf = 0.025                            # minimum (edge) uncertainty floor (fraction of profile value) 

# ----- GPR correlation length scales (in psi_N units) -----
n_ls = 0.5    # density
t_ls = 0.4    # temperature
j_ls = 0.25   # current density

# ----- Perturbation settings -----
n_equils = 15       # perturbed equilibria per baseline
jBS_scale_range = [0.8, 1.2]  # bootstrap current multiplicative range (uniform draw)
pad_psi  = 1e-3     # LCFS psi padding for TokaMaker queries

# ----- Ion species for p-file (Carbon impurity + D main + D beam) -----
ion_N = [6, 1, 1]
ion_Z = [6, 1, 1]
ion_A = [12, 2, 2]

# %% [markdown]
# ## 3. Initialize TokaMaker
#
# We create a single `TokaMaker` instance for the session, load the
# pre-built DIII-D mesh, define conductor and coil regions, and call
# `setup()` with the toroidal field $F_0 = R_0 B_0$ read from the first
# g-file.
#
# > **Note:** Only one `TokaMaker` instance can exist per Python kernel.

# %%
myOFT = OFT_env(nthreads=2)
mygs  = TokaMaker(myOFT)

# Load mesh
mesh_pts, mesh_lc, mesh_reg, coil_dict, cond_dict = load_gs_mesh('DIIID_mesh.h5')
mygs.setup_mesh(mesh_pts, mesh_lc, mesh_reg)
mygs.setup_regions(cond_dict=cond_dict, coil_dict=coil_dict)
# Out:
# #----------------------------------------------
# Open FUSION Toolkit Initialized
# Development branch:    new_bootstrap_solve
# Revision id:           4b43dd3
# Parallelization Info:
#   Not compiled with MPI
#   # of OpenMP threads =    2
# Fortran input file    = /var/folders/wz/x_qd5n8d62s0qj0_kcyyqf780000gn/T/oft_50698/oftpyin
# XML input file        = none
# Integer Precisions    =    4   8
# Float Precisions      =    4   8  16
# Complex Precisions    =    4   8
# LA backend            = native
# #----------------------------------------------
#
#
# **** Loading OFT surface mesh
#
# **** Generating surface grid level  1
#   Generating boundary domain linkage
#   Mesh statistics:
#     Area         =  1.574E+01
#     # of points  =    8910
#     # of edges   =   26567
#     # of cells   =   17658
#     # of boundary points =     160
#     # of boundary edges  =     160
#     # of boundary cells  =     160
#   Resolution statistics:
#     hmin =  8.702E-04
#     hrms =  4.833E-02
#     hmax =  1.540E-01
#   Surface grounded at vertex    1733

# %%
# Read F0 = R0*B0 from the first g-file
eqdsk_ref = read_geqdsk(geqdsks[0])
F0 = abs(eqdsk_ref.R_center * eqdsk_ref.B_center)

mygs.setup(order=3, F0=F0)
mygs.settings.maxits = 200
mygs.settings.pm = False
mygs.update_settings()

# Vertical stability coil pair (F9A/F9B antisymmetric)
mygs.set_coil_vsc({'F9A': 1.0, 'F9B': -1.0})
# Out:
# **** Creating Lagrange FE space
#   Order  =    3
#   Minlev =   -1
#
#  Computing flux BC matrix
#  Inverting real matrix
#    Time =    2.0130000000000000E-003

# %% [markdown]
# ## 4. Coil regularization
#
# TokaMaker’s inverse solver adjusts PF coil currents to match the
# isoflux and saddle-point targets.  We regularize the solution by
# providing target coil currents from a prior TokaMaker solve of this
# equilibrium.
#
# > **Note:** These target currents are specific to this DIII-D mesh and
# > equilibrium family.  For a different machine or mesh, you would need
# > to determine appropriate coil currents (e.g. from an EFIT
# > reconstruction or a prior TokaMaker run).

# %%
# Target coil currents [MA-turns] for this DIII-D mesh
target_currents = {
    'ECOILA': -0.977888676757812 / 61.0,
    'ECOILB': -0.962711173828125 / 61.0,
    'F1A':  0.115971984375,      'F1B':  0.128368578125,
    'F2A':  0.05980789453125,    'F2B':  0.0763701328125,
    'F3A': -0.03076001171875,    'F3B': -0.02234583203125,
    'F4A': -0.0401077421875,     'F4B': -0.13314096875,
    'F5A':  0.000723009033203125,'F5B':  0.000399709045410156,
    'F6A': -0.1178582578125,     'F6B': -0.15356990625,
    'F7A':  0.0341264296875,     'F7B':  0.0415082109375,
    'F8A': -0.05660116015625,    'F8B': -0.05138975390625,
    'F9A':  0.236625375,         'F9B':  0.252380265625,
}

# Convert MA-turns -> A-turns and build regularization
regularization_terms = []
for name, val in target_currents.items():
    current_A = val * 1e6
    weight = 1.0  # uniform weighting on all coils
    regularization_terms.append(
        mygs.coil_reg_term({name: 1.0}, target=current_A, weight=weight)
    )

# Small weight on the virtual VSC to allow up-down adjustment
regularization_terms.append(
    mygs.coil_reg_term({'#VSC': 1.0}, target=0.0, weight=1e-2)
)

mygs.set_coil_reg(reg_terms=regularization_terms)

# %% [markdown]
# ## 5. Reconstruct baseline equilibria
#
# For each (g-file, p-file) pair we:
#
# 1. Load the magnetic equilibrium with `read_geqdsk()`.
# 2. Load kinetic profiles with `read_pfile()` and compute the impurity
#    density (quasi-neutrality) and $Z_{\text{eff}}$.
# 3. Convert from p-file units (10$^{20}$/m$^3$, keV) to SI (m$^{-3}$,
#    eV) as required by the reconstruction routine.
# 4. Call `reconstruct_equilibrium()` which:
#    - Computes bootstrap current via TokaMaker’s Sauter model,
#    - Fits a smooth inductive $j_\phi$ profile,
#    - Iterates on the inductive scale factor until $l_i$ matches the
#      g-file value,
#    - Corrects residual $I_p$ drift.
# 5. Save the reconstructed equilibrium to the HDF5 database.

# %%
# Initialize (or overwrite) the HDF5 database
db_path = f"{header}.h5"
if os.path.exists(db_path):
    os.remove(db_path)
    print(f"Deleted existing {db_path}")

db = initialize_equilibrium_database(header)
# Out:
# Deleted existing TkMkr_D3Dlike_Hmode.h5

# %%
from scipy.interpolate import interp1d

all_results = {}   # keyed by geqdsk filename

for idx, (geqdsk_file, pfile_file) in enumerate(zip(geqdsks, pfiles)):
    print(f"\n{'='*60}")
    print(f"Reconstructing [{idx}]: {geqdsk_file}")
    print(f"  Kinetic profiles: {pfile_file}")
    print(f"{'='*60}")

    # ---- 1. Load magnetic equilibrium ----
    eqdsk = read_geqdsk(geqdsk_file)

    # ---- 2. Load kinetic profiles from p-file ----
    pf = read_pfile(pfile_file)

    # Ensure ion species are set (needed for quasi-neutrality and Zeff)
    if pf.ion_species is None:
        pf.set_ion_species(N=ion_N, Z=ion_Z, A=ion_A)

    pf.compute_quasineutrality()
    psi_pf, Zeff = pf.compute_zeff()


    # ---- 3. Convert p-file units -> SI and interpolate onto g-file grid ----
    psi_N = eqdsk.psi_N  # g-file's psi_N grid (uniform, 0 to 1)

    ne_SI   = interp1d(psi_pf, pf.ne * 1e20,  fill_value='extrapolate')(psi_N)  # m^-3
    te_SI   = interp1d(psi_pf, pf.te * 1e3,   fill_value='extrapolate')(psi_N)  # eV
    ni_SI   = interp1d(psi_pf, pf.ni * 1e20,  fill_value='extrapolate')(psi_N)  # m^-3
    ti_SI   = interp1d(psi_pf, pf.ti * 1e3,   fill_value='extrapolate')(psi_N)  # eV
    Zeff_eq = interp1d(psi_pf, Zeff,           fill_value='extrapolate')(psi_N)
    Zeff_eq = np.clip(Zeff_eq, 1.0, None)  # Zeff >= 1 by definition

    # ---- 4. Set boundary shape targets ----
    isoflux_pts = np.column_stack([eqdsk.boundary_R, eqdsk.boundary_Z])
    isoflux_weights = np.ones(len(eqdsk.boundary_R)) * 500.0
    mygs.set_isoflux(isoflux_pts, weights=isoflux_weights)

    # ---- 5. Initial guess for inductive j_phi shape ----
    nr = len(psi_N)
    guess_jinductive = create_power_flux_fun(nr, 1.5, 1.5)['y']

    # ---- 6. Reconstruct ----
    result = reconstruct_equilibrium(
        mygs, eqdsk,
        ne_SI, te_SI, ni_SI, ti_SI, Zeff_eq,
        isoflux_pts, isoflux_weights, pad_psi,
        guess_jinductive=guess_jinductive,
        n_k=5,
        psi_bridge=0.99,
        rescale_j_BS=False,
        shelf_psi_N=0.0,
        initialize_psi=True,
    )
    all_results[geqdsk_file] = result

    # ---- 7. Save reconstructed equilibrium ----
    eqdsk_out = f"{header}_count={idx}.geqdsk"
    eqdsk_out_abs = os.path.abspath(eqdsk_out)
    mygs.save_eqdsk(eqdsk_out, nr=257, nz=257,
                    truncate_eq=False, lcfs_pad=pad_psi)

    li1 = mygs.get_stats(lcfs_pad=pad_psi, li_normalization='std')['l_i']
    li3 = mygs.get_stats(lcfs_pad=pad_psi, li_normalization='iter')['l_i']

    store_equilibrium(
        header, idx, eqdsk_out_abs,
        psi_N,
        result['j_phi_fit'],
        result['j_BS_used'],
        result['j_inductive_fit'],
        ne_SI, te_SI, ni_SI, ti_SI,
        np.zeros_like(ti_SI),  # w_ExB placeholder
        li1, li3,
    )

    # Clean up the temporary geqdsk (data is in HDF5 now)
    os.remove(eqdsk_out)
    print(f"  -> Stored as count={idx}, li(1)={li1:.4f}, li(3)={li3:.4f}")
# Out:
# ============================================================
# Reconstructing [0]: TkMkr_D3Dlike_Hmode_BSamp=1.0.geqdsk
#   Kinetic profiles: TkMkr_D3Dlike_Hmode_BSamp=1.0.peqdsk
# ============================================================
#
#  >>> Matching input core j_phi with G-S solution
#
#  >>> Finding optimal j_phi scale factor
#
# --- Checking scale_j0 = 1.0000 ---
#    Input j_0:  1.2361e+06
#    Output j_0: 1.3074e+06
#    Mismatch:  5.455%
#
# --- Checking scale_j0 = 1.2000 ---
#    Input j_0:  1.4653e+06
#    Output j_0: 1.3484e+06
#    Mismatch:  8.672%
# --- Optimization Iteration 1 ---
#
# --- Checking scale_j0 = 1.0758 ---
#    Input j_0:  1.3229e+06
#    Output j_0: 1.3242e+06
#    Mismatch:  0.095%
# Converged! Optimal scale factor: 1.0758
#
#  >>> Finding optimal Ip scale factor
#
# --- Checking scale_Ip = 1.0000 ---
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.2000e+00
#    Output Ip: 1.2161e+00
#    Mismatch:  1.3420%
#
# --- Checking scale_Ip = 0.9900 ---
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.1880e+00
#    Output Ip: 1.2031e+00
#    Mismatch:  0.2510%
# --- Optimization Iteration 1 ---
#
# --- Checking scale_Ip = 0.9877 ---
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.1853e+00
#    Output Ip: 1.2000e+00
#    Mismatch:  0.0005%
# Converged! Optimal scale factor: 0.9877
#
#  >>> Iterating on H-mode equilibrium solution
# [fit] ind_scale=0.996605  bs_scale=1.000000  li_proxy=1.061179  (target=1.061179)
# [li match] target=1.065957
# [li match] iter 0: ind_factor=1.000000  li=1.081089  err=0.015132
# [li match] iter 1: ind_factor=1.050000  li=1.093672  err=0.027715
# [li match]   clamped secant 0.939875 -> 0.945000
# [li match] iter 2: ind_factor=0.945000  li=1.062274  err=-0.003683
# [li match] iter 3: ind_factor=0.957315  li=1.062233  err=-0.003724
# [li match]   clamped secant 0.000000 -> 0.861584
# [li match]   secant escaped bracket, bisection -> 0.972500
# [li match] iter 4: ind_factor=0.972500  li=1.073720  err=0.007763
# [li match] iter 5: ind_factor=0.962239  li=1.068635  err=0.002678
# [li match] iter 6: ind_factor=0.956834  li=1.061299  err=-0.004658
# [li match] iter 7: ind_factor=0.960266  li=1.062067  err=-0.003890
# [li match]   secant escaped bracket, bisection -> 0.953619
# [li match] iter 8: ind_factor=0.953619  li=1.066392  err=0.000435
# [li match] converged at iter 9: ind_factor=0.953619  li=1.066392
# [li match] final li(1)=1.066392  target=1.065957  |err|=0.000435
#
# [Ip match] desired=1200039.5  current=1198219.0  err=-0.1517%
# [Ip match] iter 0: Ip_target=1200039.5  Ip=1198219.0
# [Ip match] iter 1: Ip_target=1201862.7  Ip=1216174.5  li=1.064021
# [Ip match] iter 2: Ip_target=1200224.4  Ip=1214402.0  li=1.066730
# [Ip match] iter 3: Ip_target=1186948.2  Ip=1200030.2  li=1.067483
# [Ip match] converged at iter 4: Ip_target=1186948.2  Ip=1200030.2  li=1.067483
# [final] li(1)=1.067483  Ip=1200030.2  Ip_err=-0.0008%  li_err=0.001526
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=0.geqdsk
#   -> Stored as count=0, li(1)=1.0675, li(3)=0.8497
#
# ============================================================
# Reconstructing [1]: TkMkr_D3Dlike_Hmode_BSamp=1.25.geqdsk
#   Kinetic profiles: TkMkr_D3Dlike_Hmode_BSamp=1.25.peqdsk
# ============================================================
#
#  >>> Matching input core j_phi with G-S solution
#
#  >>> Finding optimal j_phi scale factor
#
# --- Checking scale_j0 = 1.0000 ---
#    Input j_0:  1.2302e+06
#    Output j_0: 1.2998e+06
#    Mismatch:  5.354%
#
# --- Checking scale_j0 = 1.2000 ---
#    Input j_0:  1.4583e+06
#    Output j_0: 1.3406e+06
#    Mismatch:  8.784%
# --- Optimization Iteration 1 ---
#
# --- Checking scale_j0 = 1.0743 ---
#    Input j_0:  1.3149e+06
#    Output j_0: 1.3162e+06
#    Mismatch:  0.096%
# Converged! Optimal scale factor: 1.0743
#
#  >>> Finding optimal Ip scale factor
#
# --- Checking scale_Ip = 1.0000 ---
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.2000e+00
#    Output Ip: 1.2157e+00
#    Mismatch:  1.3085%
#
# --- Checking scale_Ip = 0.9900 ---
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.1880e+00
#    Output Ip: 1.2027e+00
#    Mismatch:  0.2170%
# --- Optimization Iteration 1 ---
#
# --- Checking scale_Ip = 0.9880 ---
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.1857e+00
#    Output Ip: 1.2000e+00
#    Mismatch:  0.0001%
# Converged! Optimal scale factor: 0.9880
#
#  >>> Iterating on H-mode equilibrium solution
# [fit] ind_scale=1.010749  bs_scale=1.000000  li_proxy=0.919720  (target=0.919720)
# [li match] target=0.902988
# [li match] iter 0: ind_factor=1.000000  li=0.912790  err=0.009803
# [li match] iter 1: ind_factor=1.050000  li=0.921664  err=0.018676
# [li match]   clamped secant 0.944765 -> 0.945000
# [li match] iter 2: ind_factor=0.945000  li=0.901440  err=-0.001547
# [li match] iter 3: ind_factor=0.953034  li=0.902699  err=-0.000289
# [li match] converged at iter 4: ind_factor=0.953034  li=0.902699
# [li match] final li(1)=0.902699  target=0.902988  |err|=0.000289
#
# [Ip match] desired=1200045.6  current=1201016.3  err=+0.0809%
# [Ip match] iter 0: Ip_target=1200045.6  Ip=1201016.3
# [Ip match] iter 1: Ip_target=1199075.7  Ip=1215682.3  li=0.900807
# [Ip match] iter 2: Ip_target=1200109.8  Ip=1216820.7  li=0.900407
# [Ip match] iter 3: Ip_target=1184871.8  Ip=1200162.0  li=0.902399
# [Ip match] converged at iter 4: Ip_target=1184871.8  Ip=1200162.0  li=0.902399
# [final] li(1)=0.902399  Ip=1200162.0  Ip_err=+0.0097%  li_err=0.000588
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=1.geqdsk
#   -> Stored as count=1, li(1)=0.9024, li(3)=0.7205

# %% [markdown]
# ### Check equilibrium $l_i$ values
#
# Print the equilibrium $l_i$ (stored during reconstruction as
# `result['li_final']`) and the cylindrical proxy $l_i$ for each
# reconstructed baseline.  These are the targets that
# `generate_bouquet()` will try to match.
#
# > **Note:** Do not use `mygs.get_stats()` here — TokaMaker is
# > stateful and only holds the last solved equilibrium, so querying
# > it in a loop over multiple baselines would return the wrong $l_i$
# > for all but the last one.

# %%
from bouquet import calc_cylindrical_li_proxy

for idx, geqdsk_file in enumerate(geqdsks):
    result = all_results[geqdsk_file]
    psi_N = read_geqdsk(geqdsk_file).psi_N

    # Use the li stored during reconstruction, NOT mygs.get_stats()
    # which only reflects the last solved equilibrium.
    li_final = result['li_final']
    li_eqdsk = result['eqdsk_li']

    # Cylindrical proxy l_i (this is what the proxy filter compares)
    li_proxy = calc_cylindrical_li_proxy(mygs, result['j_phi_fit'], pad_psi)

    print(f"[{idx}] {geqdsk_file}")
    print(f"  l_i(1) [reconstructed]: {li_final:.6f}")
    print(f"  l_i(1) [g-file]:        {li_eqdsk.get('li(1)', 'N/A')}")
    print(f"  l_i (cyl proxy):        {li_proxy:.6f}")
    print(f"  proxy/reconstructed:    {li_proxy/li_final:.4f}  ({100*(li_proxy/li_final - 1):+.2f}%)")
    print()
# Out:
# [0] TkMkr_D3Dlike_Hmode_BSamp=1.0.geqdsk
#   l_i(1) [reconstructed]: 1.067483
#   l_i(1) [g-file]:        1.0659570608639612
#   l_i (cyl proxy):        1.049803
#   proxy/reconstructed:    0.9834  (-1.66%)
#
# [1] TkMkr_D3Dlike_Hmode_BSamp=1.25.geqdsk
#   l_i(1) [reconstructed]: 0.902399
#   l_i(1) [g-file]:        0.902987515530441
#   l_i (cyl proxy):        0.907827
#   proxy/reconstructed:    1.0060  (+0.60%)

# %% [markdown]
# ## 6. Verify reconstructions
#
# `plot_tokamaker_comparison()` overlays the TokaMaker solution against
# the original g-file for each reconstructed equilibrium.  The comparison
# panels include:
#
# - Total $j_\phi$ with inductive and bootstrap components
# - Pressure profile
# - Kinetic profiles ($n_e$, $T_e$, $n_i$, $T_i$)
# - Boundary shape deviation
# - $l_i$ and $I_p$ error
#
# Call with `plot_idx=None` for a multi-panel overview of all
# reconstructions, or with a specific index for a single-shot deep dive.

# %%
# Overview of all reconstructions
plot_tokamaker_comparison(mygs, all_results)

# %%
# Detailed single-shot comparison for the first equilibrium
plot_tokamaker_comparison(mygs, all_results, plot_idx=0)
# Out:
# --- Summary for TkMkr_D3Dlike_Hmode_BSamp=1.0.geqdsk ---
#   bs_factor_final : 1.000000
#   li(1) achieved  : 1.067483
#   j_phi RMS error : 43663.80 A/m^2  (0.0437 MA/m^2)
#   eqdsk Ip        : 1200040 A
#   TokaMaker Ip    : 1200030 A  (-0.001%)
#   Boundary dev.   : max=24.44 mm  RMS=3.98 mm

# %% [markdown]
# ## 7. Generate perturbed equilibrium families
#
# For each reconstructed baseline, `generate_bouquet()`:
#
# 1. Draws GPR-perturbed density, temperature, and $j_\phi$ profiles
#    using the specified uncertainties and correlation lengths.
# 2. Recomputes the bootstrap current for each perturbed profile set
#    (when `recalculate_j_BS=True`).
# 3. Iteratively adjusts the inductive current profile to match the
#    baseline $l_i$ within the specified tolerance.
# 4. Archives each equilibrium (g-file bytes + profiles) to the HDF5
#    database.
#
# The `jBS_scale_range` parameter applies a random multiplicative factor
# to the bootstrap current for each sample, drawn uniformly from the
# specified range (e.g. [0.8, 1.2] gives ±20% variation).  This
# captures uncertainty in the bootstrap model itself, independent of the
# kinetic profile perturbations.
#
# The resulting database is self-contained: it stores baseline profiles,
# uncertainties, and all perturbed equilibria, so `plot_bouquet()` only
# needs the file path.
#
# > **Note:** For finer control of the $j_\phi$ correlation structure,
# > bouquet also provides `sigmoid_length_scale()` which creates a
# > spatially-varying GPR length scale — broad in the core and short
# > near the edge to preserve narrow features like the bootstrap spike.
# > Pass the result as `j_ls` instead of a scalar.  See
# > `bouquet.sigmoid_length_scale` for details.

# %%
for idx, geqdsk_file in enumerate(geqdsks):
    print(f"\n{'='*60}")
    print(f"Generating {n_equils} perturbed equilibria for [{idx}]: {geqdsk_file}")
    print(f"{'='*60}")

    eqdsk  = read_geqdsk(geqdsk_file)
    result = all_results[geqdsk_file]
    psi_N  = eqdsk.psi_N

    # Re-extract SI profiles from the reconstruction result
    ne_SI = result['ne']
    te_SI = result['te']
    ni_SI = result['ni']
    ti_SI = result['ti']
    Zeff_eq = result['Zeff']

    # Build radially-varying 1-sigma uncertainty profiles
    # Tighter in the pedestal where Thomson is well-constrained,
    # wider in the core and near the separatrix.
    sigma_ne   = new_uncertainty_profiles(psi_N, frac_ne,   falloff_exp=falloff_ne,   shelf=shelf) * ne_SI
    sigma_te   = new_uncertainty_profiles(psi_N, frac_te,   falloff_exp=falloff_te,   shelf=shelf) * te_SI
    sigma_ni   = new_uncertainty_profiles(psi_N, frac_ni,   falloff_exp=falloff_ni,   shelf=shelf) * ni_SI
    sigma_ti   = new_uncertainty_profiles(psi_N, frac_ti,   falloff_exp=falloff_ti,   shelf=shelf) * ti_SI
    sigma_jphi = frac_jphi * np.abs(result['j_phi_fit'])

    # Targets from the reconstruction
    # NOTE: Do NOT use mygs.get_stats() here — TokaMaker only holds
    # the last solved equilibrium.  Use the li stored during
    # reconstruction instead.
    Ip_target  = abs(eqdsk.Ip)
    l_i_target = result['li_final']
    print(f"  l_i target = {l_i_target:.6f} (from reconstruction)")

    # Read the baseline g-file and p-file as raw bytes for HDF5 archival
    with open(geqdsk_file, 'rb') as fh:
        baseline_eqdsk_raw = fh.read()
    pfile_file = pfiles[idx]
    with open(pfile_file, 'rb') as fh:
        pfile_raw_bytes = fh.read()

    # Restore isoflux targets for this equilibrium
    mygs.set_isoflux(result['isoflux_pts'], weights=result['weights'])

    # Generate the family
    diagnostics = generate_bouquet(
        mygs, psi_N, n_equils, header,
        result['j_phi_fit'],
        ne_SI, te_SI, ni_SI, ti_SI,
        sigma_ne, sigma_te, sigma_ni, sigma_ti, sigma_jphi,
        n_ls, t_ls, j_ls,
        Ip_target, l_i_target, Zeff_eq,
        input_jinductive=result['j_inductive_fit'],
        l_i_tolerance=10,
        l_i_proxy_threshold=12.5,
        psi_pad=pad_psi,
        constrain_sawteeth=True,
        recalculate_j_BS=True,
        jBS_scale_range=jBS_scale_range,
        pfile_bytes=pfile_raw_bytes,
        baseline_eqdsk_bytes=baseline_eqdsk_raw,
        baseline_pfile_bytes=pfile_raw_bytes,
        diagnostic_plots=False,
        scan_val=idx,
    )

    print(f"  -> {len(diagnostics)} equilibria archived")
# Out:
# ============================================================
# Generating 15 perturbed equilibria for [0]: TkMkr_D3Dlike_Hmode_BSamp=1.0.geqdsk
# ============================================================
#   l_i target = 1.067483 (from reconstruction)
# Bouquet:   0%|          | 0/15 [00:00<?, ?eq/s]
# ============================================================
#   Equilibrium 1/15  (scale_jBS=0.8345)
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 8 draws (1.0s, err=0.452%)
#   [li_iter=1] find_optimal_scale: 6.1s
#   l_i target (equil):   1.0675
#   proxy target:         1.1093  (corrected)
#   matched l_i (equil):  1.2421
#   matched l_i (proxy):  1.2301
#   Ip error vs target:   0.063%
#   proxy vs real l_i:    -0.97%
#   |l_i - l_i_target|:   0.1746
#   [li_iter=2] Proxy matched in 28 draws (2.5s, err=1.323%)
#   [li_iter=2] find_optimal_scale: 7.2s
#   l_i target (equil):   1.0675
#   proxy target:         1.0877  (corrected)
#   matched l_i (equil):  1.0829
#   matched l_i (proxy):  1.0940
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +1.03%
#   |l_i - l_i_target|:   0.0154
#   Wall-clock time: 34.8s  (total: 0.6 min, avg: 34.8s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=0.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=0.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=0.geqdsk
#
# ============================================================
#   Equilibrium 2/15  (scale_jBS=1.0937)  ETA: 8.1 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 4 draws (0.3s, err=0.648%)
#   [li_iter=1] find_optimal_scale: 4.6s
# Skipping this equilibrium, q_0 < 1.0 (pre-check)
#   [li_iter=2] Proxy matched in 6 draws (0.5s, err=0.598%)
#   [li_iter=2] find_optimal_scale: 6.8s
#   l_i target (equil):   1.0675
#   proxy target:         1.0779  (corrected)
#   matched l_i (equil):  1.1185
#   matched l_i (proxy):  1.1129
#   Ip error vs target:   0.035%
#   proxy vs real l_i:    -0.50%
#   |l_i - l_i_target|:   0.0510
#   [li_iter=3] Proxy matched in 3 draws (0.4s, err=1.407%)
#   [li_iter=3] find_optimal_scale: 7.3s
#   l_i target (equil):   1.0675
#   proxy target:         1.0720  (corrected)
#   matched l_i (equil):  1.0777
#   matched l_i (proxy):  1.0797
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.19%
#   |l_i - l_i_target|:   0.0102
#   Wall-clock time: 36.5s  (total: 1.2 min, avg: 35.7s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=1.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=1.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=1.geqdsk
#
# ============================================================
#   Equilibrium 3/15  (scale_jBS=1.1863)  ETA: 7.7 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 24 draws (1.3s, err=1.387%)
#   [li_iter=1] find_optimal_scale: 7.4s
#   l_i target (equil):   1.0675
#   proxy target:         1.0589  (corrected)
#   matched l_i (equil):  1.1129
#   matched l_i (proxy):  1.1006
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    -1.10%
#   |l_i - l_i_target|:   0.0454
#   [li_iter=2] Proxy matched in 4 draws (0.4s, err=0.685%)
#   [li_iter=2] find_optimal_scale: 7.4s
#   l_i target (equil):   1.0675
#   proxy target:         1.0619  (corrected)
#   matched l_i (equil):  1.0786
#   matched l_i (proxy):  1.0743
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    -0.40%
#   |l_i - l_i_target|:   0.0111
#   Wall-clock time: 33.5s  (total: 1.8 min, avg: 34.9s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=2.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=2.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=2.geqdsk
#
# ============================================================
#   Equilibrium 4/15  (scale_jBS=0.8440)  ETA: 7.0 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 19 draws (1.4s, err=1.435%)
#   [li_iter=1] find_optimal_scale: 4.3s
# Skipping this equilibrium, q_0 < 1.0 (pre-check)
#   [li_iter=2] Proxy matched in 10 draws (0.7s, err=0.314%)
#   [li_iter=2] find_optimal_scale: 3.6s
#   l_i target (equil):   1.0675
#   proxy target:         1.0955  (corrected)
#   matched l_i (equil):  1.1956
#   matched l_i (proxy):  1.1847
#   Ip error vs target:   0.082%
#   proxy vs real l_i:    -0.91%
#   |l_i - l_i_target|:   0.1281
#   [li_iter=3] Proxy matched in 9 draws (0.8s, err=0.816%)
#   [li_iter=3] find_optimal_scale: 6.1s
#   l_i target (equil):   1.0675
#   proxy target:         1.0774  (corrected)
#   matched l_i (equil):  1.1040
#   matched l_i (proxy):  1.1061
#   Ip error vs target:   0.040%
#   proxy vs real l_i:    +0.20%
#   |l_i - l_i_target|:   0.0365
#   [li_iter=4] Proxy matched in 27 draws (2.3s, err=1.356%)
#   [li_iter=4] find_optimal_scale: 3.5s
#   l_i target (equil):   1.0675
#   proxy target:         1.0744  (corrected)
#   matched l_i (equil):  1.0549
#   matched l_i (proxy):  1.0606
#   Ip error vs target:   0.033%
#   proxy vs real l_i:    +0.53%
#   |l_i - l_i_target|:   0.0125
#   Wall-clock time: 43.3s  (total: 2.5 min, avg: 37.0s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=3.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=3.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=3.geqdsk
#
# ============================================================
#   Equilibrium 5/15  (scale_jBS=0.9478)  ETA: 6.8 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 17 draws (1.2s, err=1.426%)
#   [li_iter=1] find_optimal_scale: 6.2s
#   l_i target (equil):   1.0675
#   proxy target:         1.0863  (corrected)
#   matched l_i (equil):  1.2044
#   matched l_i (proxy):  1.1890
#   Ip error vs target:   0.042%
#   proxy vs real l_i:    -1.28%
#   |l_i - l_i_target|:   0.1369
#   [li_iter=2] Proxy matched in 13 draws (1.0s, err=1.463%)
#   [li_iter=2] find_optimal_scale: 7.3s
#   l_i target (equil):   1.0675
#   proxy target:         1.0804  (corrected)
#   matched l_i (equil):  1.0651
#   matched l_i (proxy):  1.0754
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.97%
#   |l_i - l_i_target|:   0.0024
#   Wall-clock time: 35.7s  (total: 3.1 min, avg: 36.8s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=4.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=4.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=4.geqdsk
#
# ============================================================
#   Equilibrium 6/15  (scale_jBS=1.0573)  ETA: 6.1 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 15 draws (1.1s, err=0.612%)
#   [li_iter=1] find_optimal_scale: 6.2s
#   l_i target (equil):   1.0675
#   proxy target:         1.0573  (corrected)
#   matched l_i (equil):  1.0896
#   matched l_i (proxy):  1.0747
#   Ip error vs target:   0.016%
#   proxy vs real l_i:    -1.37%
#   |l_i - l_i_target|:   0.0221
#   Wall-clock time: 21.9s  (total: 3.5 min, avg: 34.3s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=5.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=5.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=5.geqdsk
#
# ============================================================
#   Equilibrium 7/15  (scale_jBS=0.9241)  ETA: 5.1 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 1 draws (0.2s, err=1.400%)
#   [li_iter=1] find_optimal_scale: 7.5s
#   l_i target (equil):   1.0675
#   proxy target:         1.0859  (corrected)
#   matched l_i (equil):  1.1806
#   matched l_i (proxy):  1.1706
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    -0.85%
#   |l_i - l_i_target|:   0.1131
#   [li_iter=2] Proxy matched in 23 draws (1.6s, err=0.199%)
#   [li_iter=2] find_optimal_scale: 6.2s
#   l_i target (equil):   1.0675
#   proxy target:         1.0690  (corrected)
#   matched l_i (equil):  1.0997
#   matched l_i (proxy):  1.0938
#   Ip error vs target:   0.013%
#   proxy vs real l_i:    -0.53%
#   |l_i - l_i_target|:   0.0322
#   [li_iter=3] Proxy matched in 8 draws (0.7s, err=0.926%)
#   [li_iter=3] find_optimal_scale: 6.1s
#   l_i target (equil):   1.0675
#   proxy target:         1.0624  (corrected)
#   matched l_i (equil):  1.0912
#   matched l_i (proxy):  1.0831
#   Ip error vs target:   0.031%
#   proxy vs real l_i:    -0.74%
#   |l_i - l_i_target|:   0.0237
#   Wall-clock time: 44.9s  (total: 4.3 min, avg: 35.8s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=6.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=6.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=6.geqdsk
#
# ============================================================
#   Equilibrium 8/15  (scale_jBS=1.1366)  ETA: 4.8 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 21 draws (1.6s, err=0.219%)
#   [li_iter=1] find_optimal_scale: 4.5s
# Skipping this equilibrium, q_0 < 1.0 (pre-check)
#   [li_iter=2] Proxy matched in 7 draws (0.8s, err=0.609%)
#   [li_iter=2] find_optimal_scale: 7.6s
#   l_i target (equil):   1.0675
#   proxy target:         1.0630  (corrected)
#   matched l_i (equil):  1.1218
#   matched l_i (proxy):  1.1053
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    -1.47%
#   |l_i - l_i_target|:   0.0543
#   [li_iter=3] Proxy matched in 11 draws (1.1s, err=0.622%)
#   [li_iter=3] find_optimal_scale: 7.7s
#   l_i target (equil):   1.0675
#   proxy target:         1.0610  (corrected)
#   matched l_i (equil):  1.0859
#   matched l_i (proxy):  1.0784
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    -0.69%
#   |l_i - l_i_target|:   0.0184
#   Wall-clock time: 44.2s  (total: 5.0 min, avg: 36.9s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=7.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=7.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=7.geqdsk
#
# ============================================================
#   Equilibrium 9/15  (scale_jBS=1.0315)  ETA: 4.3 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 1 draws (0.2s, err=1.447%)
#   [li_iter=1] find_optimal_scale: 6.6s
#   l_i target (equil):   1.0675
#   proxy target:         1.0664  (corrected)
#   matched l_i (equil):  1.1481
#   matched l_i (proxy):  1.1340
#   Ip error vs target:   0.027%
#   proxy vs real l_i:    -1.22%
#   |l_i - l_i_target|:   0.0806
#   [li_iter=2] Proxy matched in 3 draws (0.5s, err=0.470%)
#   [li_iter=2] find_optimal_scale: 6.3s
#   l_i target (equil):   1.0675
#   proxy target:         1.0736  (corrected)
#   matched l_i (equil):  1.0383
#   matched l_i (proxy):  1.0473
#   Ip error vs target:   0.025%
#   proxy vs real l_i:    +0.87%
#   |l_i - l_i_target|:   0.0292
#   Wall-clock time: 28.9s  (total: 5.5 min, avg: 36.0s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=8.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=8.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=8.geqdsk
#
# ============================================================
#   Equilibrium 10/15  (scale_jBS=1.0505)  ETA: 3.6 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 4 draws (0.4s, err=0.825%)
#   [li_iter=1] find_optimal_scale: 6.0s
#   l_i target (equil):   1.0675
#   proxy target:         1.0594  (corrected)
#   matched l_i (equil):  1.1153
#   matched l_i (proxy):  1.1007
#   Ip error vs target:   0.028%
#   proxy vs real l_i:    -1.31%
#   |l_i - l_i_target|:   0.0478
#   [li_iter=2] Proxy matched in 3 draws (0.2s, err=1.103%)
#   [li_iter=2] find_optimal_scale: 6.3s
#   l_i target (equil):   1.0675
#   proxy target:         1.0554  (corrected)
#   matched l_i (equil):  1.0696
#   matched l_i (proxy):  1.0558
#   Ip error vs target:   0.013%
#   proxy vs real l_i:    -1.30%
#   |l_i - l_i_target|:   0.0022
#   Wall-clock time: 30.5s  (total: 6.0 min, avg: 35.4s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=9.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=9.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=9.geqdsk
#
# ============================================================
#   Equilibrium 11/15  (scale_jBS=0.8495)  ETA: 3.0 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 14 draws (1.1s, err=1.184%)
#   [li_iter=1] find_optimal_scale: 7.4s
#   l_i target (equil):   1.0675
#   proxy target:         1.0927  (corrected)
#   matched l_i (equil):  1.1617
#   matched l_i (proxy):  1.1546
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    -0.61%
#   |l_i - l_i_target|:   0.0942
#   [li_iter=2] Proxy matched in 8 draws (0.5s, err=0.251%)
#   [li_iter=2] find_optimal_scale: 4.8s
#   l_i target (equil):   1.0675
#   proxy target:         1.0786  (corrected)
#   matched l_i (equil):  1.0825
#   matched l_i (proxy):  1.0877
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.48%
#   |l_i - l_i_target|:   0.0150
#   Wall-clock time: 33.1s  (total: 6.6 min, avg: 35.2s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=10.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=10.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=10.geqdsk
#
# ============================================================
#   Equilibrium 12/15  (scale_jBS=1.0200)  ETA: 2.3 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 19 draws (1.9s, err=1.067%)
#   [li_iter=1] find_optimal_scale: 3.4s
# Skipping this equilibrium, q_0 < 1.0 (pre-check)
#   [li_iter=2] Proxy matched in 3 draws (0.5s, err=0.638%)
#   [li_iter=2] find_optimal_scale: 6.6s
#   l_i target (equil):   1.0675
#   proxy target:         1.0452  (corrected)
#   matched l_i (equil):  1.0993
#   matched l_i (proxy):  1.0622
#   Ip error vs target:   0.073%
#   proxy vs real l_i:    -3.37%
#   |l_i - l_i_target|:   0.0318
#   [li_iter=3] Proxy matched in 4 draws (0.4s, err=0.912%)
#   [li_iter=3] find_optimal_scale: 6.4s
#   l_i target (equil):   1.0675
#   proxy target:         1.0511  (corrected)
#   matched l_i (equil):  1.0607
#   matched l_i (proxy):  1.0469
#   Ip error vs target:   0.006%
#   proxy vs real l_i:    -1.30%
#   |l_i - l_i_target|:   0.0068
#   Wall-clock time: 43.8s  (total: 7.3 min, avg: 35.9s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=11.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=11.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=11.geqdsk
#
# ============================================================
#   Equilibrium 13/15  (scale_jBS=0.8548)  ETA: 1.8 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 13 draws (0.9s, err=0.355%)
#   [li_iter=1] find_optimal_scale: 4.5s
# Skipping this equilibrium, q_0 < 1.0 (pre-check)
#   [li_iter=2] Proxy matched in 1 draws (0.2s, err=1.384%)
#   [li_iter=2] find_optimal_scale: 7.6s
#   l_i target (equil):   1.0675
#   proxy target:         1.1117  (corrected)
#   matched l_i (equil):  1.1606
#   matched l_i (proxy):  1.1675
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.59%
#   |l_i - l_i_target|:   0.0931
#   [li_iter=3] Proxy matched in 27 draws (1.2s, err=0.124%)
#   [li_iter=3] find_optimal_scale: 6.1s
#   l_i target (equil):   1.0675
#   proxy target:         1.0753  (corrected)
#   matched l_i (equil):  1.1310
#   matched l_i (proxy):  1.1227
#   Ip error vs target:   0.093%
#   proxy vs real l_i:    -0.73%
#   |l_i - l_i_target|:   0.0635
#   [li_iter=4] Proxy matched in 4 draws (0.2s, err=1.287%)
#   [li_iter=4] find_optimal_scale: 6.1s
#   l_i target (equil):   1.0675
#   proxy target:         1.0691  (corrected)
#   matched l_i (equil):  1.0902
#   matched l_i (proxy):  1.0891
#   Ip error vs target:   0.073%
#   proxy vs real l_i:    -0.09%
#   |l_i - l_i_target|:   0.0227
#   Wall-clock time: 48.0s  (total: 8.1 min, avg: 36.9s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=12.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=12.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=12.geqdsk
#
# ============================================================
#   Equilibrium 14/15  (scale_jBS=1.0174)  ETA: 1.2 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 11 draws (0.9s, err=0.628%)
#   [li_iter=1] find_optimal_scale: 4.7s
# Skipping this equilibrium, q_0 < 1.0 (pre-check)
#   [li_iter=2] Proxy matched in 16 draws (0.9s, err=1.192%)
#   [li_iter=2] find_optimal_scale: 6.7s
#   l_i target (equil):   1.0675
#   proxy target:         1.0855  (corrected)
#   matched l_i (equil):  1.1373
#   matched l_i (proxy):  1.1342
#   Ip error vs target:   0.040%
#   proxy vs real l_i:    -0.27%
#   |l_i - l_i_target|:   0.0698
#   [li_iter=3] Proxy matched in 5 draws (0.5s, err=0.423%)
#   [li_iter=3] find_optimal_scale: 7.3s
#   l_i target (equil):   1.0675
#   proxy target:         1.0691  (corrected)
#   matched l_i (equil):  1.1028
#   matched l_i (proxy):  1.0971
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    -0.51%
#   |l_i - l_i_target|:   0.0353
#   [li_iter=4] Proxy matched in 11 draws (0.7s, err=0.392%)
#   [li_iter=4] find_optimal_scale: 3.6s
#   l_i target (equil):   1.0675
#   proxy target:         1.0696  (corrected)
#   matched l_i (equil):  1.0684
#   matched l_i (proxy):  1.0707
#   Ip error vs target:   0.016%
#   proxy vs real l_i:    +0.22%
#   |l_i - l_i_target|:   0.0009
#   Wall-clock time: 42.8s  (total: 8.9 min, avg: 37.3s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=13.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=13.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=13.geqdsk
#
# ============================================================
#   Equilibrium 15/15  (scale_jBS=0.8189)  ETA: 0.6 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 7 draws (0.7s, err=0.310%)
#   [li_iter=1] find_optimal_scale: 7.4s
#   l_i target (equil):   1.0675
#   proxy target:         1.0966  (corrected)
#   matched l_i (equil):  1.2297
#   matched l_i (proxy):  1.2127
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    -1.38%
#   |l_i - l_i_target|:   0.1622
#   [li_iter=2] Proxy matched in 18 draws (1.0s, err=1.328%)
#   [li_iter=2] find_optimal_scale: 6.4s
#   l_i target (equil):   1.0675
#   proxy target:         1.0722  (corrected)
#   matched l_i (equil):  1.1182
#   matched l_i (proxy):  1.1122
#   Ip error vs target:   0.029%
#   proxy vs real l_i:    -0.54%
#   |l_i - l_i_target|:   0.0507
#   [li_iter=3] Proxy matched in 1 draws (0.2s, err=1.437%)
#   [li_iter=3] find_optimal_scale: 3.5s
#   l_i target (equil):   1.0675
#   proxy target:         1.0741  (corrected)
#   matched l_i (equil):  1.0471
#   matched l_i (proxy):  1.0544
#   Ip error vs target:   0.005%
#   proxy vs real l_i:    +0.70%
#   |l_i - l_i_target|:   0.0204
#   Wall-clock time: 41.2s  (total: 9.6 min, avg: 37.5s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=14.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=14.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=14.geqdsk
#   -> 15 equilibria archived
#
# ============================================================
# Generating 15 perturbed equilibria for [1]: TkMkr_D3Dlike_Hmode_BSamp=1.25.geqdsk
# ============================================================
#   l_i target = 0.902399 (from reconstruction)
# Bouquet:   0%|          | 0/15 [00:00<?, ?eq/s]
# ============================================================
#   Equilibrium 1/15  (scale_jBS=0.9171)
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 6 draws (0.6s, err=0.417%)
#   [li_iter=1] find_optimal_scale: 8.0s
#   l_i target (equil):   0.9024
#   proxy target:         0.9275  (corrected)
#   matched l_i (equil):  0.9558
#   matched l_i (proxy):  0.9819
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    +2.72%
#   |l_i - l_i_target|:   0.0534
#   [li_iter=2] Proxy matched in 16 draws (1.9s, err=0.123%)
#   [li_iter=2] find_optimal_scale: 7.1s
#   l_i target (equil):   0.9024
#   proxy target:         0.9126  (corrected)
#   matched l_i (equil):  0.9319
#   matched l_i (proxy):  0.9359
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.43%
#   |l_i - l_i_target|:   0.0295
#   Wall-clock time: 34.9s  (total: 0.6 min, avg: 34.9s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=0.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=0.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=0.geqdsk
#
# ============================================================
#   Equilibrium 2/15  (scale_jBS=1.1180)  ETA: 8.1 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 15 draws (1.7s, err=0.026%)
#   [li_iter=1] find_optimal_scale: 7.1s
#   l_i target (equil):   0.9024
#   proxy target:         0.9052  (corrected)
#   matched l_i (equil):  0.9324
#   matched l_i (proxy):  0.9382
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    +0.63%
#   |l_i - l_i_target|:   0.0300
#   Wall-clock time: 24.9s  (total: 1.0 min, avg: 29.9s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=1.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=1.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=1.geqdsk
#
# ============================================================
#   Equilibrium 3/15  (scale_jBS=1.0218)  ETA: 6.5 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 11 draws (1.2s, err=0.549%)
#   [li_iter=1] find_optimal_scale: 7.0s
#   l_i target (equil):   0.9024
#   proxy target:         0.8901  (corrected)
#   matched l_i (equil):  0.9034
#   matched l_i (proxy):  0.9069
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    +0.39%
#   |l_i - l_i_target|:   0.0010
#   Wall-clock time: 23.8s  (total: 1.4 min, avg: 27.9s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=2.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=2.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=2.geqdsk
#
# ============================================================
#   Equilibrium 4/15  (scale_jBS=0.9367)  ETA: 5.6 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 5 draws (0.7s, err=0.646%)
#   [li_iter=1] find_optimal_scale: 6.9s
#   l_i target (equil):   0.9024
#   proxy target:         0.9184  (corrected)
#   matched l_i (equil):  0.9671
#   matched l_i (proxy):  0.9724
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.55%
#   |l_i - l_i_target|:   0.0647
#   [li_iter=2] Proxy matched in 11 draws (1.2s, err=0.994%)
#   [li_iter=2] find_optimal_scale: 8.2s
#   l_i target (equil):   0.9024
#   proxy target:         0.9216  (corrected)
#   matched l_i (equil):  0.9583
#   matched l_i (proxy):  0.9802
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +2.28%
#   |l_i - l_i_target|:   0.0559
#   [li_iter=3] Proxy matched in 3 draws (0.5s, err=1.423%)
#   [li_iter=3] find_optimal_scale: 7.3s
#   l_i target (equil):   0.9024
#   proxy target:         0.9194  (corrected)
#   matched l_i (equil):  0.9297
#   matched l_i (proxy):  0.9463
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    +1.79%
#   |l_i - l_i_target|:   0.0273
#   Wall-clock time: 42.5s  (total: 2.1 min, avg: 31.5s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=3.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=3.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=3.geqdsk
#
# ============================================================
#   Equilibrium 5/15  (scale_jBS=0.8477)  ETA: 5.8 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 6 draws (0.6s, err=0.817%)
#   [li_iter=1] find_optimal_scale: 6.6s
#   l_i target (equil):   0.9024
#   proxy target:         0.9119  (corrected)
#   matched l_i (equil):  0.9563
#   matched l_i (proxy):  0.9595
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.33%
#   |l_i - l_i_target|:   0.0539
#   [li_iter=2] Proxy matched in 2 draws (0.2s, err=1.229%)
#   [li_iter=2] find_optimal_scale: 5.6s
#   l_i target (equil):   0.9024
#   proxy target:         0.9093  (corrected)
#   matched l_i (equil):  0.9284
#   matched l_i (proxy):  0.9343
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.63%
#   |l_i - l_i_target|:   0.0260
#   Wall-clock time: 37.7s  (total: 2.8 min, avg: 32.7s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=4.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=4.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=4.geqdsk
#
# ============================================================
#   Equilibrium 6/15  (scale_jBS=1.0142)  ETA: 5.5 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 4 draws (0.5s, err=0.034%)
#   [li_iter=1] find_optimal_scale: 6.3s
#   l_i target (equil):   0.9024
#   proxy target:         0.9017  (corrected)
#   matched l_i (equil):  0.9357
#   matched l_i (proxy):  0.9363
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.07%
#   |l_i - l_i_target|:   0.0333
#   [li_iter=2] Proxy matched in 9 draws (1.2s, err=1.306%)
#   [li_iter=2] find_optimal_scale: 6.2s
#   l_i target (equil):   0.9024
#   proxy target:         0.9054  (corrected)
#   matched l_i (equil):  0.9477
#   matched l_i (proxy):  0.9525
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    +0.51%
#   |l_i - l_i_target|:   0.0453
#   [li_iter=3] Proxy matched in 5 draws (0.7s, err=0.085%)
#   [li_iter=3] find_optimal_scale: 8.1s
#   l_i target (equil):   0.9024
#   proxy target:         0.9088  (corrected)
#   matched l_i (equil):  0.9542
#   matched l_i (proxy):  0.9625
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.87%
#   |l_i - l_i_target|:   0.0518
#   [li_iter=4] Proxy matched in 16 draws (1.9s, err=0.010%)
#   [li_iter=4] find_optimal_scale: 7.1s
#   l_i target (equil):   0.9024
#   proxy target:         0.9083  (corrected)
#   matched l_i (equil):  0.9181
#   matched l_i (proxy):  0.9239
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.63%
#   |l_i - l_i_target|:   0.0157
#   Wall-clock time: 52.7s  (total: 3.7 min, avg: 36.1s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=5.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=5.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=5.geqdsk
#
# ============================================================
#   Equilibrium 7/15  (scale_jBS=0.9488)  ETA: 5.4 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 25 draws (2.5s, err=0.751%)
#   [li_iter=1] find_optimal_scale: 7.1s
#   l_i target (equil):   0.9024
#   proxy target:         0.9345  (corrected)
#   matched l_i (equil):  1.0352
#   matched l_i (proxy):  1.0363
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.10%
#   |l_i - l_i_target|:   0.1328
#   [li_iter=2] Proxy matched in 7 draws (0.7s, err=0.658%)
#   [li_iter=2] find_optimal_scale: 7.4s
#   l_i target (equil):   0.9024
#   proxy target:         0.9285  (corrected)
#   matched l_i (equil):  0.9206
#   matched l_i (proxy):  0.9445
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +2.60%
#   |l_i - l_i_target|:   0.0182
#   Wall-clock time: 39.4s  (total: 4.3 min, avg: 36.6s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=6.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=6.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=6.geqdsk
#
# ============================================================
#   Equilibrium 8/15  (scale_jBS=0.9267)  ETA: 4.9 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 14 draws (1.5s, err=0.195%)
#   [li_iter=1] find_optimal_scale: 6.5s
#   l_i target (equil):   0.9024
#   proxy target:         0.9201  (corrected)
#   matched l_i (equil):  0.9305
#   matched l_i (proxy):  0.9449
#   Ip error vs target:   0.039%
#   proxy vs real l_i:    +1.55%
#   |l_i - l_i_target|:   0.0281
#   Wall-clock time: 25.8s  (total: 4.8 min, avg: 35.2s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=7.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=7.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=7.geqdsk
#
# ============================================================
#   Equilibrium 9/15  (scale_jBS=0.9021)  ETA: 4.1 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 17 draws (1.7s, err=0.931%)
#   [li_iter=1] find_optimal_scale: 7.2s
#   l_i target (equil):   0.9024
#   proxy target:         0.9166  (corrected)
#   matched l_i (equil):  0.9666
#   matched l_i (proxy):  0.9711
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    +0.48%
#   |l_i - l_i_target|:   0.0642
#   [li_iter=2] Proxy matched in 1 draws (0.2s, err=0.438%)
#   [li_iter=2] find_optimal_scale: 7.3s
#   l_i target (equil):   0.9024
#   proxy target:         0.9112  (corrected)
#   matched l_i (equil):  0.9309
#   matched l_i (proxy):  0.9375
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    +0.71%
#   |l_i - l_i_target|:   0.0285
#   Wall-clock time: 33.3s  (total: 5.4 min, avg: 35.0s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=8.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=8.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=8.geqdsk
#
# ============================================================
#   Equilibrium 10/15  (scale_jBS=1.1872)  ETA: 3.5 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 2 draws (0.4s, err=0.546%)
#   [li_iter=1] find_optimal_scale: 7.4s
#   l_i target (equil):   0.9024
#   proxy target:         0.9069  (corrected)
#   matched l_i (equil):  0.9187
#   matched l_i (proxy):  0.9274
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.94%
#   |l_i - l_i_target|:   0.0163
#   Wall-clock time: 24.5s  (total: 5.8 min, avg: 33.9s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=9.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=9.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=9.geqdsk
#
# ============================================================
#   Equilibrium 11/15  (scale_jBS=1.1989)  ETA: 2.8 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 7 draws (1.0s, err=0.200%)
#   [li_iter=1] find_optimal_scale: 6.0s
#   l_i target (equil):   0.9024
#   proxy target:         0.8805  (corrected)
#   matched l_i (equil):  0.8775
#   matched l_i (proxy):  0.8764
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    -0.13%
#   |l_i - l_i_target|:   0.0249
#   Wall-clock time: 24.5s  (total: 6.2 min, avg: 33.1s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=10.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=10.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=10.geqdsk
#
# ============================================================
#   Equilibrium 12/15  (scale_jBS=0.8104)  ETA: 2.2 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 1 draws (0.2s, err=0.082%)
#   [li_iter=1] find_optimal_scale: 7.0s
#   l_i target (equil):   0.9024
#   proxy target:         0.9343  (corrected)
#   matched l_i (equil):  1.0485
#   matched l_i (proxy):  1.0424
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    -0.58%
#   |l_i - l_i_target|:   0.1461
#   [li_iter=2] Proxy matched in 7 draws (1.0s, err=1.309%)
#   [li_iter=2] find_optimal_scale: 7.0s
#   l_i target (equil):   0.9024
#   proxy target:         0.9309  (corrected)
#   matched l_i (equil):  0.9295
#   matched l_i (proxy):  0.9573
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    +2.99%
#   |l_i - l_i_target|:   0.0271
#   Wall-clock time: 33.8s  (total: 6.8 min, avg: 33.1s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=11.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=11.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=11.geqdsk
#
# ============================================================
#   Equilibrium 13/15  (scale_jBS=0.8297)  ETA: 1.7 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 24 draws (2.6s, err=0.821%)
#   [li_iter=1] find_optimal_scale: 5.7s
#   l_i target (equil):   0.9024
#   proxy target:         0.9156  (corrected)
#   matched l_i (equil):  1.0134
#   matched l_i (proxy):  1.0046
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    -0.87%
#   |l_i - l_i_target|:   0.1110
#   [li_iter=2] Proxy matched in 2 draws (0.4s, err=0.265%)
#   [li_iter=2] find_optimal_scale: 5.9s
#   l_i target (equil):   0.9024
#   proxy target:         0.9255  (corrected)
#   matched l_i (equil):  0.8981
#   matched l_i (proxy):  0.9254
#   Ip error vs target:   0.079%
#   proxy vs real l_i:    +3.03%
#   |l_i - l_i_target|:   0.0043
#   Wall-clock time: 32.5s  (total: 7.3 min, avg: 33.1s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=12.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=12.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=12.geqdsk
#
# ============================================================
#   Equilibrium 14/15  (scale_jBS=0.8004)  ETA: 1.1 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 8 draws (1.0s, err=0.418%)
#   [li_iter=1] find_optimal_scale: 7.0s
#   l_i target (equil):   0.9024
#   proxy target:         0.9101  (corrected)
#   matched l_i (equil):  0.9467
#   matched l_i (proxy):  0.9480
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.14%
#   |l_i - l_i_target|:   0.0443
#   [li_iter=2] Proxy matched in 7 draws (0.8s, err=0.678%)
#   [li_iter=2] find_optimal_scale: 4.2s
#   l_i target (equil):   0.9024
#   proxy target:         0.9003  (corrected)
#   matched l_i (equil):  0.9586
#   matched l_i (proxy):  0.9518
#   Ip error vs target:   0.040%
#   proxy vs real l_i:    -0.70%
#   |l_i - l_i_target|:   0.0562
#   [li_iter=3] Proxy matched in 3 draws (0.3s, err=0.326%)
#   [li_iter=3] find_optimal_scale: 6.4s
#   l_i target (equil):   0.9024
#   proxy target:         0.9073  (corrected)
#   matched l_i (equil):  0.9292
#   matched l_i (proxy):  0.9374
#   Ip error vs target:   0.000%
#   proxy vs real l_i:    +0.87%
#   |l_i - l_i_target|:   0.0268
#   Wall-clock time: 37.9s  (total: 8.0 min, avg: 33.4s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=13.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=13.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=13.geqdsk
#
# ============================================================
#   Equilibrium 15/15  (scale_jBS=1.0330)  ETA: 0.6 min
# ============================================================
# Searching for pressure profile match...
#   [li_iter=1] Proxy matched in 11 draws (1.3s, err=0.864%)
#   [li_iter=1] find_optimal_scale: 6.8s
#   l_i target (equil):   0.9024
#   proxy target:         0.9073  (corrected)
#   matched l_i (equil):  0.9400
#   matched l_i (proxy):  0.9446
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    +0.50%
#   |l_i - l_i_target|:   0.0376
#   [li_iter=2] Proxy matched in 5 draws (0.6s, err=0.860%)
#   [li_iter=2] find_optimal_scale: 6.8s
#   l_i target (equil):   0.9024
#   proxy target:         0.9072  (corrected)
#   matched l_i (equil):  0.9265
#   matched l_i (proxy):  0.9314
#   Ip error vs target:   0.001%
#   proxy vs real l_i:    +0.53%
#   |l_i - l_i_target|:   0.0241
#   Wall-clock time: 33.0s  (total: 8.5 min, avg: 33.4s/eq)
#   Saving to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=14.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=14.geqdsk
#   Deleted temporary file: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=14.geqdsk
#   -> 15 equilibria archived

# %% [markdown]
# ## 8. Visualize perturbed families
#
# `plot_bouquet()` reads the HDF5 database and overlays all perturbed
# equilibria against the baseline.  Available modes:
#
# | Mode | Panels |
# |---|---|
# | `"kinetic"` | $n_e$, $n_i$, $T_e$, $T_i$ with uncertainty bands |
# | `"pressure"` | Thermal pressure |
# | `"j-phi"` | Total $j_\phi$, $j_{\text{ind}}$, $j_{\text{BS}}$ |
# | `"all"` | All of the above |

# %%
# Plot all panels for the first baseline (scan_value=0)
plot_bouquet(header, scan_value=0, mode="all")
# Out:
# ([<Figure size 800x500 with 4 Axes>,
#   <Figure size 600x400 with 1 Axes>,
#   <Figure size 600x400 with 1 Axes>,
#   <Figure size 600x600 with 2 Axes>,
#   <Figure size 1000x500 with 2 Axes>],
#  [array([[<Axes: ylabel='n [m$^{-3}$]'>, <Axes: >],
#          [<Axes: xlabel='$\\hat{\\psi}$', ylabel='T [keV]'>,
#           <Axes: xlabel='$\\hat{\\psi}$'>]], dtype=object),
#   <Axes: xlabel='$\\hat{\\psi}$', ylabel='Pressure [kPa]'>,
#   <Axes: xlabel='$\\hat{\\psi}$', ylabel='$j_\\phi$ [MA/m$^2$]'>,
#   array([<Axes: ylabel='$j_{\\rm BS}$ [MA/m$^2$]'>,
#          <Axes: xlabel='$\\hat{\\psi}$', ylabel='$j_{\\rm inductive}$ [MA/m$^2$]'>],
#         dtype=object),
#   array([<Axes: title={'center': 'LCFS shape variation'}, xlabel='R [m]', ylabel='Z [m]'>,
#          <Axes: title={'center': 'LCFS deviation from baseline'}, xlabel='Perturbation index', ylabel='Boundary deviation [mm]'>],
#         dtype=object)])

# %%
# Plot all panels for the second baseline (scan_value=1)
plot_bouquet(header, scan_value=1, mode="all")
# Out:
# ([<Figure size 800x500 with 4 Axes>,
#   <Figure size 600x400 with 1 Axes>,
#   <Figure size 600x400 with 1 Axes>,
#   <Figure size 600x600 with 2 Axes>,
#   <Figure size 1000x500 with 2 Axes>],
#  [array([[<Axes: ylabel='n [m$^{-3}$]'>, <Axes: >],
#          [<Axes: xlabel='$\\hat{\\psi}$', ylabel='T [keV]'>,
#           <Axes: xlabel='$\\hat{\\psi}$'>]], dtype=object),
#   <Axes: xlabel='$\\hat{\\psi}$', ylabel='Pressure [kPa]'>,
#   <Axes: xlabel='$\\hat{\\psi}$', ylabel='$j_\\phi$ [MA/m$^2$]'>,
#   array([<Axes: ylabel='$j_{\\rm BS}$ [MA/m$^2$]'>,
#          <Axes: xlabel='$\\hat{\\psi}$', ylabel='$j_{\\rm inductive}$ [MA/m$^2$]'>],
#         dtype=object),
#   array([<Axes: title={'center': 'LCFS shape variation'}, xlabel='R [m]', ylabel='Z [m]'>,
#          <Axes: title={'center': 'LCFS deviation from baseline'}, xlabel='Perturbation index', ylabel='Boundary deviation [mm]'>],
#         dtype=object)])

# %%
# Trace plots: l_i, Ip, and boundary deviation across all equilibria
figs = plot_traces(header, scan_value='all')
plt.show()

# %% [markdown]
# ## 9. Inspect individual equilibria and profiles
#
# `plot_geqdsk_bouquet()` provides a quick overview of any g-file
# (flux surfaces, pressure, q, j_phi, P' and FF').  `plot_pfile_bouquet()`
# shows all kinetic profiles from a p-file.  Both support switching
# between $\psi_N$ and $\rho$ coordinates via the `x_coord` flag.

# %%
from bouquet import plot_geqdsk_bouquet

# Inspect both baseline g-files
plot_geqdsk_bouquet(geqdsks,x_coord="rho")
# Out:
# /Users/danielburgess/Desktop/plasma/bouquet/bouquet/plotting.py:1189: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax_ff.legend(fontsize=7)
# /Users/danielburgess/Desktop/plasma/bouquet/bouquet/plotting.py:1195: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# (<Figure size 1400x600 with 5 Axes>,
#  [<Axes: title={'center': 'Flux surfaces'}, xlabel='R [m]', ylabel='Z [m]'>,
#   <Axes: title={'center': 'Pressure'}, ylabel='Pressure [kPa]'>,
#   <Axes: title={'center': 'Safety factor'}, ylabel='q'>,
#   <Axes: title={'center': '$|J_\\phi|$ (std)  [$B_t$:+, $I_p$:+]'}, xlabel='$\\rho$', ylabel='$|\\langle J_\\phi \\rangle|$ [MA/m$^2$]'>,
#   <Axes: title={'center': "$p'$ and $FF'$ (normalized)"}, xlabel='$\\rho$', ylabel='Normalized'>])

# %%
# Inspect all perturbed g-files

plot_geqdsk_bouquet(h5path=f"{header}.h5", x_coord="rho")
# Out:
# (<Figure size 1400x600 with 5 Axes>,
#  [<Axes: title={'center': 'Flux surfaces'}, xlabel='R [m]', ylabel='Z [m]'>,
#   <Axes: title={'center': 'Pressure'}, ylabel='Pressure [kPa]'>,
#   <Axes: title={'center': 'Safety factor'}, ylabel='q'>,
#   <Axes: title={'center': '$|J_\\phi|$ (std)  [$B_t$:+, $I_p$:+]'}, xlabel='$\\rho$', ylabel='$|\\langle J_\\phi \\rangle|$ [MA/m$^2$]'>,
#   <Axes: title={'center': "$p'$ and $FF'$ (normalized)"}, xlabel='$\\rho$', ylabel='Normalized'>])

# %%
from bouquet import plot_pfile_bouquet

# Inspect the first baseline p-file (with rho coordinate)
eq_ref = read_geqdsk(geqdsks[0])
plot_pfile_bouquet(pfiles[0], x_coord="rho", eq=eq_ref)
# Out:
# (<Figure size 1600x840 with 15 Axes>,
#  array([[<Axes: title={'center': '$n_e$'}, ylabel='$10^{20}$/m$^3$'>,
#          <Axes: title={'center': '$T_e$'}, ylabel='keV'>,
#          <Axes: title={'center': '$n_i$'}, ylabel='$10^{20}$/m$^3$'>,
#          <Axes: title={'center': '$T_i$'}, ylabel='keV'>,
#          <Axes: title={'center': '$p_{\\rm tot}$'}, ylabel='kPa'>],
#         [<Axes: title={'center': '$n_{z1}$'}, ylabel='$10^{20}$/m$^3$'>,
#          <Axes: title={'center': '$Z_{\\rm eff}$'}>,
#          <Axes: title={'center': '$\\omega_{E \\times B}$'}, ylabel='kRad/s'>,
#          <Axes: title={'center': '$\\omega_{\\rm dia}$'}, ylabel='kRad/s'>,
#          <Axes: title={'center': '$E_r$'}, ylabel='kV/m'>],
#         [<Axes: title={'center': '$\\omega_{\\rm HB}$'}, xlabel='$\\rho$', ylabel='kRad/s'>,
#          <Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object))

# %%
# Inspect all perturbed p-files

plot_pfile_bouquet(h5path=f"{header}.h5", scan_val=0, x_coord="psi_N")
# Out:
# (<Figure size 1600x840 with 15 Axes>,
#  array([[<Axes: title={'center': '$n_e$'}, ylabel='$10^{20}$/m$^3$'>,
#          <Axes: title={'center': '$T_e$'}, ylabel='keV'>,
#          <Axes: title={'center': '$n_i$'}, ylabel='$10^{20}$/m$^3$'>,
#          <Axes: title={'center': '$T_i$'}, ylabel='keV'>,
#          <Axes: title={'center': '$p_{\\rm tot}$'}, ylabel='kPa'>],
#         [<Axes: title={'center': '$n_{z1}$'}, ylabel='$10^{20}$/m$^3$'>,
#          <Axes: title={'center': '$Z_{\\rm eff}$'}>,
#          <Axes: title={'center': '$\\omega_{E \\times B}$'}, ylabel='kRad/s'>,
#          <Axes: title={'center': '$\\omega_{\\rm dia}$'}, ylabel='kRad/s'>,
#          <Axes: title={'center': '$E_r$'}, ylabel='kV/m'>],
#         [<Axes: title={'center': '$\\omega_{\\rm HB}$'}, xlabel='$\\psi_N$', ylabel='kRad/s'>,
#          <Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object))

# %% [markdown]
# ## 10. Coil current variation
#
# `plot_coil_currents()` shows how the PF coil currents vary across
# the bouquet of perturbed equilibria.  This is useful for checking
# that the shape control system is not being pushed to its limits.

# %%
from bouquet import plot_coil_currents

# Coil currents for the first scan value
plot_coil_currents(header, scan_val=0)
# Out:
# (<Figure size 1000x500 with 1 Axes>,
#  <Axes: title={'center': 'Coil currents across bouquet'}, ylabel='Coil current [kA]'>)
