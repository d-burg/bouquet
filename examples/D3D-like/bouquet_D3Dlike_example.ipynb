# %% [markdown]
# TokaMaker Example: Vertical stability in DIII-D from a gEQDSK equilibrium {#doc_tMaker_DIIID_ex2}
# ==========
# In this example we demonstrate:
#
# 1) How to reproduce a DIII-D equilibrium using an inverse solve from EFIT by reading in inputs from a gEQDSK file.
# 2) How to reproduce a DIII-D equilibrium using an forward solve from EFIT by reading in inputs from a gEQDSK file.
# 3) How to compute linear growth rates and perform time-dependent simulation of a Vertical Displacement Event (VDE) using this equilibrium
#
# This example utilizes the mesh built in \ref doc_tMaker_DIIID_ex1.
#
# **Note:** Running this example requires the [h5py](https://www.h5py.org/) python package, which is installable using `pip` or other standard methods.

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# ## Load TokaMaker library
#
# To load the TokaMaker python module we need to tell python where to the module is located. This can be done either through the `PYTHONPATH` environment variable or using within a script using `sys.path.append()` as below, where we look for the environement variable `OFT_ROOTPATH` to provide the path to where the OpenFUSIONToolkit is installed (`/Applications/OFT` on macOS).

# %%
tokamaker_python_path = '/Users/danielburgess/Desktop/plasma/OpenFUSIONToolkit/build_release'
if tokamaker_python_path is not None:
    sys.path.append(os.path.join(tokamaker_python_path,'python'))
    
from OpenFUSIONToolkit import OFT_env
from OpenFUSIONToolkit.TokaMaker import TokaMaker
from OpenFUSIONToolkit.TokaMaker.meshing import gs_Domain, save_gs_mesh, load_gs_mesh
from OpenFUSIONToolkit.TokaMaker import util
from OpenFUSIONToolkit.TokaMaker.util import create_isoflux, read_eqdsk, create_power_flux_fun, get_jphi_from_GS
from OpenFUSIONToolkit.TokaMaker.bootstrap import solve_with_bootstrap, find_optimal_scale

# %%
from bouquet import (generate_perturbed_equilibria, 
                     store_equilibrium, 
                     initialize_equilibrium_database, 
                     read_geqdsk, 
                     calc_cylindrical_li_proxy,
                     fit_inductive_profile,
                     plot_tokamaker_comparison,
                     reconstruct_equilibrium)

# %%
### specify input geqdsks and kinetic profile files here

geqdsks = ['TkMkr_D3Dlike_Hmode_BSamp=1.0.geqdsk','TkMkr_D3Dlike_Hmode_BSamp=1.25.geqdsk']
kin_files = ['TkMkr_D3Dlike_Hmode_BSamp=1.0.txt', 'TkMkr_D3Dlike_Hmode_BSamp=1.25.txt']

# %%
def read_gpeckf(filename):
    """
    Reads a whitespace-separated data file and returns a dictionary with column names as keys
    and lists of values as dictionary values.
    
    Parameters:
    filename (str): Path to the input file
    
    Returns:
    dict: Dictionary where keys are column names and values are lists of data
    """
    data_dict = {}
    
    with open(filename, 'r') as file:
        # Read the header line and extract column names
        header = file.readline().strip()
        column_names = header.split()
        
        # Initialize empty lists for each column
        for col_name in column_names:
            data_dict[col_name] = []
        
        # Read data lines
        for line in file:
            line = line.strip()
            if line:  # Skip empty lines
                values = line.split()
                # Add each value to its corresponding column list
                for i, value in enumerate(values):
                    try:
                        # Convert to float (since the data appears to be numerical)
                        data_dict[column_names[i]].append(float(value))
                    except ValueError:
                        # If conversion fails, store as string
                        data_dict[column_names[i]].append(value)
    
    return data_dict

# %% [markdown]
# ## Compute equilibria
#
# ### Initialize TokaMaker object
# We create a TokaMaker instance to use for equilibrium calculations. Note at present only a single instance can be used per python kernel, so this command should only be called **once** in a given Jupyter notebook or python script. In the future this restriction may be relaxed.

# %%
myOFT = OFT_env(nthreads=2)
mygs = TokaMaker(myOFT)
# Out:
# #----------------------------------------------
# Open FUSION Toolkit Initialized
# Development branch:    new_bootstrap_solve
# Revision id:           f5a4096
# Parallelization Info:
#   Not compiled with MPI
#   # of OpenMP threads =    2
# Fortran input file    = /var/folders/wz/x_qd5n8d62s0qj0_kcyyqf780000gn/T/oft_38452/oftpyin
# XML input file        = none
# Integer Precisions    =    4   8
# Float Precisions      =    4   8  16
# Complex Precisions    =    4   8
# LA backend            = native
# #----------------------------------------------

# %% [markdown]
# ### Update default settings
#
# Sometimes it is useful to modify the default TokaMaker settings. Here we update one setting to help with convergence:
# - `mygs.settings.maxits`: This sets the maximum non-linear iteration count for G-S solver, and should often be increased from the default setting of 40 iterations.
#
# Settings can be modified before running \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.setup "setup()" or at any time during execution by adjusting desired values and then calling \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.update_settings "update_settings()".

# %%
mygs.settings.maxits = 200
pad_psi = 1e-4

# %% [markdown]
# ### Load mesh into TokaMaker
# Now we load the mesh generated in \ref doc_tMaker_DIIID_ex1 using \ref OpenFUSIONToolkit.TokaMaker.load_gs_mesh "load_gs_mesh()" and \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.setup_mesh "setup_mesh". Then we use \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.setup_regions "setup_regions()", passing the conductor and coil dictionaries for the mesh, to define the different region types. Finally, we call \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.setup "setup()" to setup the required solver objects. During this call we can specify the desired element order (min=2, max=4) and the toroidal field through F0 = B0*R0, where B0 is the toroidal field at a reference location R0.

# %%
mesh_pts,mesh_lc,mesh_reg,coil_dict,cond_dict = load_gs_mesh('DIIID_mesh.h5')
mygs.setup_mesh(mesh_pts, mesh_lc, mesh_reg)
mygs.setup_regions(cond_dict=cond_dict,coil_dict=coil_dict)
# Out:
# **** Loading OFT surface mesh
#
# **** Generating surface grid level  1
#   Generating boundary domain linkage
#   Mesh statistics:
#     Area         =  1.574E+01
#     # of points  =    8910
#     # of edges   =   26567
#     # of cells   =   17658
#     # of boundary points =     160
#     # of boundary edges  =     160
#     # of boundary cells  =     160
#   Resolution statistics:
#     hmin =  8.702E-04
#     hrms =  4.833E-02
#     hmax =  1.540E-01
#   Surface grounded at vertex    1733

# %%
# Get toroidal field from one eqdsk
eqdsk = read_geqdsk(geqdsks[0])
mygs.setup(order=3,F0=abs(eqdsk.R_center*eqdsk.B_center))
# Out:
# **** Creating Lagrange FE space
#   Order  =    3
#   Minlev =   -1
#
#  Computing flux BC matrix
#  Inverting real matrix
#    Time =    1.9480000000000001E-003

# %% [markdown]
# ### Define a vertical stability coil
# Like many elongated equilibria, the equilibrium we seek to compute below is vertically unstable. In this case we use the `F9A` and `F9B` pair of poloidal field coils for vertical stability in order to help with convergence.

# %%
mygs.set_coil_vsc({'F9A': 1.0, 'F9B': -1.0})

# %% [markdown]
# ## Compute Inverse Equilibrium
#
# ### Define global quantities and targets
# For the inverse case we define a target for the plasma current and the peak plasma pressure, which occurs on the magnetic axis.
#
# **Note:** These constraints can be considered "hard" constraints, where they will be matched to good tolerance as long as the calculation converges.

# %% [markdown]
# ### Define shape targets
# In order to constrain the shape of the plasma we can utilize two types of constraints:
#  1. `isoflux` points, which are points we want to lie on the same flux surface (eg. the LCFS)
#  2. `saddle` points, where we want the poloidal magnetic field to vanish (eg. X-points).
#
# **Note:** These constraints can be considered "soft" constraints, where the calculation attempts to minimize error in satisfying these constraints subject to other constraints and regularization.
#
# Here we use the contour defining the last closed flux surface as our `isoflux` constraint, and do not set any `saddle` targets.

# %%
pad_psi = 1e-3

# %% [markdown]
# ### Define coil regularization matrix
#
# We aim to reproduce the gEQDSK equilibrium from EFIT with equivalent coil currents, so we use the current regularization matrix to constrain the TokaMaker coil currents to be close to the target values.
#
# In this case, `coil_reg_mat` is an identity matrix with size `mygs.ncoils`+1 that maps each coil to its target current value. `coil_reg_targets` is a vector of length `mygs.ncoils`+1 containing the target current values.  `coil_reg_weights` is a vector of length `mygs.ncoils`+1 which contains values corresponding to how strongly each condition is enforced by the solver.  In this solve, the weights on the `ECOILs` are set high to prevent deviation from the target currents. Additionally, if a given poloidal field coil is found to have significant deviations from the target value, the weight on that coil can be increased, as is done below for `F5A` and `F5B`.

# %%
target_currents = {
    'ECOILA': -0.977888676757812/61.0,
    'ECOILB': -0.962711173828125/61.0,
    'F1A': 0.115971984375,
    'F2A': 0.05980789453125,
    'F3A': -0.03076001171875,
    'F4A': -0.0401077421875,
    'F5A': 0.000723009033203125,
    'F6A': -0.1178582578125,
    'F7A': 0.0341264296875,
    'F8A': -0.05660116015625,
    'F9A': 0.236625375,
    'F1B': 0.128368578125,
    'F2B': 0.0763701328125,
    'F3B': -0.02234583203125,
    'F4B': -0.13314096875,
    'F5B': 0.000399709045410156,
    'F6B': -0.15356990625,
    'F7B': 0.0415082109375,
    'F8B': -0.05138975390625,
    'F9B': 0.252380265625
}
for key in target_currents:
    target_currents[key] *= 1.E6

# Set regularization weights
regularization_terms = []
for name, target_current in target_currents.items():
    # Set specific target currents from input equilibrium and different weights depending on the coil set
    if name.startswith('ECOIL'):
        regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=target_current,weight=1.0))
    elif name.startswith('F'):
        if name.startswith('F5'):
            regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=target_current,weight=1.))
        else:
            regularization_terms.append(mygs.coil_reg_term({name: 1.0},target=target_current,weight=1.))
# Set zero target current and small weight on virtual VSC to allow up-down adjustment
regularization_terms.append(mygs.coil_reg_term({'#VSC': 1.0},target=0.0,weight=1.E-2))

# Pass regularization terms to TokaMaker
mygs.set_coil_reg(reg_terms=regularization_terms)

# %% [markdown]
# ### Define flux functions
# Although TokaMaker has a "default" profile for the F\*F' and P' terms this should almost never be used and one should instead choose an appropriate flux function for their application. In this case we use the P' and F\*F' profiles directly from the gEQDSK we are working to reproduce.

# %% [markdown]
# ### Compute equilibrium
# We can now compute a free-boundary equilibrium using these constraints. Note that before running a calculation for the first time we must initialize the flux function $\psi$, which can be done using \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.init_psi "init_psi()". This subroutine initializes the flux using the specified Ip_target from above, which is evenly distributed over the entire plasma region or only with a boundary defined using a center point (R,Z), minor radius (a), and elongation and triangularity. Coil currents are also initialized at this point using the constraints above and this uniform plasma current initialization.
#
# \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.solve "solve()" is then called to compute a self-consitent Grad-Shafranov equilibrium. If the result variable (`err_flag`) is zero then the solution has converged to the desired tolerance ($10^{-6}$ by default).

# %%
header = 'TkMkr_D3Dlike_Hmode'

db_path = f"{header}.h5"
if os.path.exists(db_path):
    os.remove(db_path)
    print(f"Deleted {db_path}")
    
db = initialize_equilibrium_database(header)
# Out:
# Deleted TkMkr_D3Dlike_Hmode.h5

# %%
from scipy.interpolate import interp1d

psi_pad = 1e-3
all_results = {}

pcount = 0

for i,geqdsk_str in enumerate(geqdsks):

    eqdsk = read_geqdsk(geqdsk_str)
    kin = read_gpeckf(kin_files[i])

    ne = np.array(kin['ne[m^-3]'])
    te = np.array(kin['te[eV]'])
    ni = np.array(kin['ni[m^-3]'])
    ti = np.array(kin['ti[eV]'])

    # Approximate Zeff assuming carbon (Z=6) as dominant impurity (typical DIII-D graphite wall)
    # From quasi-neutrality: ne = n_D + Z_C * n_C  =>  n_C = (ne - ni) / Z_C
    # Zeff = (n_D + Z_C^2 * n_C) / ne = 6 - 5*(ni/ne)
    Zeff = 6.0 - 5.0 * (ni / ne)
    Zeff = np.clip(Zeff, 1.0, None)  # Zeff >= 1 by definition
    kin_psi = np.array(kin['psi'])

    psi_eqdsk = eqdsk.psi_N

    ne = interp1d(kin_psi, ne, kind='linear', fill_value='extrapolate')(psi_eqdsk)
    te = interp1d(kin_psi, te, kind='linear', fill_value='extrapolate')(psi_eqdsk)
    ni = interp1d(kin_psi, ni, kind='linear', fill_value='extrapolate')(psi_eqdsk)
    ti = interp1d(kin_psi, ti, kind='linear', fill_value='extrapolate')(psi_eqdsk)
    Zeff = interp1d(kin_psi, Zeff, kind='linear', fill_value='extrapolate')(psi_eqdsk)

    # ---- 1. Set strict boundary target ----
    isoflux_pts = np.column_stack([eqdsk.boundary_R, eqdsk.boundary_Z])
    isoflux_weights = np.ones(len(eqdsk.boundary_R)) * 500.0
    mygs.set_isoflux(isoflux_pts, weights=isoflux_weights)

    nr = len(eqdsk.psi_N)
    guess_jinductive = create_power_flux_fun(nr, 1.5, 1.5)['y']

    all_results[geqdsk_str] = reconstruct_equilibrium(
        mygs, eqdsk, ne, te, ni, ti, Zeff,
        isoflux_pts, isoflux_weights, psi_pad,
        guess_jinductive=guess_jinductive,
        n_k=5, # FROM 3 to 5
        psi_bridge=0.99,
        rescale_j_BS=False,
        shelf_psi_N=0.0,
        initialize_psi=True
    )

    eqdsk_filename = header + '_count=' + str(pcount) + '.geqdsk'

    # Get the full absolute path
    full_path = os.path.abspath(eqdsk_filename)

    print(f"File will be saved to: {full_path}")

    mygs.save_eqdsk(eqdsk_filename, 
                    nr = 257, 
                    nz = 257,  
                    truncate_eq=False, 
                    lcfs_pad=pad_psi)
        
    li1 = mygs.get_stats(lcfs_pad=pad_psi, li_normalization='std')['l_i']
    li3 = mygs.get_stats(lcfs_pad=pad_psi, li_normalization='iter')['l_i']

    store_equilibrium(
        header, pcount, full_path,
        eqdsk.psi_N, all_results[geqdsk_str]['j_phi_fit'], 
        all_results[geqdsk_str]['j_BS_used'], 
        all_results[geqdsk_str]['j_inductive_fit'],
        ne, te, ni, ti, np.zeros_like(ti),
        li1, li3)
    
    # Delete output eqdsk file after storing inside HDF5
    target_file = eqdsk_filename
    try:
        os.remove(target_file)
        print(f"Successfully deleted: {target_file}")
    except FileNotFoundError:
        print(f"Error: {target_file} not found.")
    except PermissionError:
        print(f"Error: Permission denied to delete {target_file}.")
# Out:
#  >>> Matching input core j_phi with G-S solution
# Starting non-linear GS solver
#      1  1.0000E+00  9.3176E-01  3.3197E-02  1.7456E+00 -1.3786E-01  3.2066E+05
# WARNING: Candidate X-point and O-point converged to the same location   1.74E+00 -9.26E-02   1.74E+00 -9.26E-02
#      2  1.0000E+00  4.3701E-01  1.9461E-02  1.7419E+00 -9.2638E-02  1.8356E+05
#      3  1.0000E+00  4.4648E-01  8.8354E-03  1.7429E+00 -5.8531E-02  1.0768E+05
#      4  1.0000E+00  4.6819E-01  4.4943E-03  1.7451E+00 -3.6202E-02  9.0165E+04
#      5  1.0000E+00  4.7684E-01  2.0622E-03  1.7467E+00 -2.2914E-02  8.6519E+04
#      6  1.0000E+00  4.7939E-01  1.0485E-03  1.7476E+00 -1.5335E-02  8.4469E+04
#      7  1.0000E+00  4.7998E-01  5.5530E-04  1.7481E+00 -1.1075E-02  8.3411E+04
#      8  1.0000E+00  4.8006E-01  2.9943E-04  1.7483E+00 -8.6892E-03  8.2819E+04
#      9  1.0000E+00  4.8003E-01  1.6875E-04  1.7485E+00 -7.3543E-03  8.2474E+04
#     10  1.0000E+00  4.8000E-01  9.4153E-05  1.7485E+00 -6.6071E-03  8.2301E+04
#     11  1.0000E+00  4.7998E-01  5.2846E-05  1.7485E+00 -6.1889E-03  8.2190E+04
#     12  1.0000E+00  4.7996E-01  2.9604E-05  1.7486E+00 -5.9548E-03  8.2128E+04
#     13  1.0000E+00  4.7996E-01  1.6929E-05  1.7486E+00 -5.8237E-03  8.2093E+04
#     14  1.0000E+00  4.7995E-01  8.4809E-06  1.7486E+00 -5.7503E-03  8.2125E+04
#     15  1.0000E+00  4.7995E-01  4.8886E-06  1.7486E+00 -5.7092E-03  8.2114E+04
#     16  1.0000E+00  4.7995E-01  2.8288E-06  1.7486E+00 -5.6862E-03  8.2108E+04
#     17  1.0000E+00  4.7995E-01  1.6046E-06  1.7486E+00 -5.6733E-03  8.2104E+04
#     18  1.0000E+00  4.7995E-01  9.0311E-07  1.7486E+00 -5.6661E-03  8.2102E+04
#  Timing:   2.2810449996031821
#    Source:    0.74603800103068352
#    Solve:     0.23596499860286713
#    Boundary:   1.0440999642014503E-002
#    Other:      1.2886010003276169
#
#  >>> Finding optimal j_phi scale factor
#
# --- Checking scale_j0 = 1.0000 ---
# Starting non-linear GS solver
#      1  1.0000E+00  4.7995E-01  3.4506E-03  1.7480E+00 -5.7059E-03  8.3176E+04
#      2  1.0000E+00  4.6565E-01  5.5403E-04  1.7471E+00 -5.7732E-03  8.4076E+04
#      3  1.0000E+00  4.6220E-01  1.7462E-04  1.7466E+00 -5.8156E-03  8.4308E+04
#      4  1.0000E+00  4.6124E-01  7.1331E-05  1.7463E+00 -5.8392E-03  8.4327E+04
#      5  1.0000E+00  4.6095E-01  3.1495E-05  1.7462E+00 -5.8521E-03  8.4327E+04
#      6  1.0000E+00  4.6086E-01  1.5264E-05  1.7461E+00 -5.8591E-03  8.4329E+04
#      7  1.0000E+00  4.6083E-01  7.4738E-06  1.7461E+00 -5.8631E-03  8.4329E+04
#      8  1.0000E+00  4.6082E-01  3.6015E-06  1.7461E+00 -5.8653E-03  8.4330E+04
#      9  1.0000E+00  4.6082E-01  1.6963E-06  1.7461E+00 -5.8665E-03  8.4330E+04
#     10  1.0000E+00  4.6082E-01  8.1479E-07  1.7461E+00 -5.8673E-03  8.4330E+04
#  Timing:   1.2792379995808005
#    Source:    0.42512999940663576
#    Solve:     0.13011300005018711
#    Boundary:   6.1319996602833271E-003
#    Other:     0.71786300046369433
#    Input j_0:  1.2398e+06
#    Output j_0: 1.3098e+06
#    Mismatch:  5.349%
#
# --- Checking scale_j0 = 1.2000 ---
# Starting non-linear GS solver
#      1  1.0000E+00  4.6082E-01  1.9354E-03  1.7458E+00 -5.8845E-03  8.4574E+04
#      2  1.0000E+00  4.5290E-01  3.3812E-04  1.7453E+00 -5.9148E-03  8.4986E+04
#      3  1.0000E+00  4.5091E-01  8.7091E-05  1.7450E+00 -5.9331E-03  8.5029E+04
#      4  1.0000E+00  4.5036E-01  2.8858E-05  1.7449E+00 -5.9427E-03  8.5016E+04
#      5  1.0000E+00  4.5019E-01  1.5800E-05  1.7448E+00 -5.9476E-03  8.5029E+04
#      6  1.0000E+00  4.5014E-01  7.7241E-06  1.7448E+00 -5.9501E-03  8.5027E+04
#      7  1.0000E+00  4.5012E-01  3.8193E-06  1.7448E+00 -5.9514E-03  8.5026E+04
#      8  1.0000E+00  4.5011E-01  1.8650E-06  1.7448E+00 -5.9521E-03  8.5025E+04
#      9  1.0000E+00  4.5011E-01  8.9801E-07  1.7448E+00 -5.9525E-03  8.5025E+04
#  Timing:   1.2136909998953342
#    Source:    0.42053700098767877
#    Solve:     0.12537600006908178
#    Boundary:   6.1079999431967735E-003
#    Other:     0.66166999889537692
#    Input j_0:  1.4699e+06
#    Output j_0: 1.3507e+06
#    Mismatch:  8.827%
# --- Optimization Iteration 1 ---
#
# --- Checking scale_j0 = 1.0740 ---
# Starting non-linear GS solver
#      1  1.0000E+00  4.5011E-01  1.1497E-03  1.7449E+00 -5.9451E-03  8.4972E+04
#      2  1.0000E+00  4.5481E-01  2.0018E-04  1.7452E+00 -5.9280E-03  8.4661E+04
#      3  1.0000E+00  4.5600E-01  5.4152E-05  1.7454E+00 -5.9173E-03  8.4622E+04
#      4  1.0000E+00  4.5633E-01  2.3547E-05  1.7455E+00 -5.9116E-03  8.4610E+04
#      5  1.0000E+00  4.5643E-01  9.6321E-06  1.7455E+00 -5.9087E-03  8.4609E+04
#      6  1.0000E+00  4.5646E-01  4.7345E-06  1.7455E+00 -5.9071E-03  8.4609E+04
#      7  1.0000E+00  4.5646E-01  2.2978E-06  1.7455E+00 -5.9063E-03  8.4609E+04
#      8  1.0000E+00  4.5647E-01  1.0929E-06  1.7455E+00 -5.9059E-03  8.4609E+04
#      9  1.0000E+00  4.5647E-01  5.3033E-07  1.7455E+00 -5.9057E-03  8.4609E+04
#  Timing:   1.1893079997971654
#    Source:    0.38510100031271577
#    Solve:     0.12095399899408221
#    Boundary:   5.8860001154243946E-003
#    Other:     0.67736700037494302
#    Input j_0:  1.3250e+06
#    Output j_0: 1.3262e+06
#    Mismatch:  0.094%
# Converged! Optimal scale factor: 1.0740
#
#  >>> Finding optimal Ip scale factor
#
# --- Checking scale_Ip = 1.0000 ---
# Starting non-linear GS solver
#      1  1.0000E+00  4.5647E-01  2.5677E-07  1.7455E+00 -5.9055E-03  8.4609E+04
#  Timing:  0.22336300043389201
#    Source:     7.8559000045061111E-002
#    Solve:      1.5399999916553497E-002
#    Boundary:   1.1860001832246780E-003
#    Other:     0.12821800028905272
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.2000e+00
#    Output Ip: 1.2161e+00
#    Mismatch:  1.3382%
#
# --- Checking scale_Ip = 0.9000 ---
# Starting non-linear GS solver
#      1  1.0000E+00  4.5647E-01  6.0079E-03  1.7479E+00 -5.6539E-03  7.6944E+04
#      2  1.0000E+00  4.9654E-01  1.0205E-03  1.7510E+00 -5.2733E-03  7.7051E+04
#      3  1.0000E+00  5.0560E-01  5.1621E-04  1.7529E+00 -4.9909E-03  7.7226E+04
#      4  1.0000E+00  5.0734E-01  2.6533E-04  1.7537E+00 -4.8092E-03  7.7259E+04
#      5  1.0000E+00  5.0760E-01  1.2872E-04  1.7541E+00 -4.6974E-03  7.7261E+04
#      6  1.0000E+00  5.0760E-01  6.0461E-05  1.7543E+00 -4.6299E-03  7.7249E+04
#      7  1.0000E+00  5.0757E-01  2.8477E-05  1.7544E+00 -4.5897E-03  7.7240E+04
#      8  1.0000E+00  5.0755E-01  1.3086E-05  1.7544E+00 -4.5659E-03  7.7233E+04
#      9  1.0000E+00  5.0754E-01  5.9415E-06  1.7544E+00 -4.5519E-03  7.7229E+04
#     10  1.0000E+00  5.0754E-01  2.8311E-06  1.7545E+00 -4.5437E-03  7.7226E+04
#     11  1.0000E+00  5.0754E-01  1.3427E-06  1.7545E+00 -4.5389E-03  7.7225E+04
#     12  1.0000E+00  5.0754E-01  6.5726E-07  1.7545E+00 -4.5361E-03  7.7224E+04
#  Timing:   1.5316679999232292
#    Source:    0.50707900151610374
#    Solve:     0.16018900088965893
#    Boundary:   7.8620002605021000E-003
#    Other:     0.85653799725696445
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.0800e+00
#    Output Ip: 1.0847e+00
#    Mismatch:  9.6117%
# --- Optimization Iteration 1 ---
#
# --- Checking scale_Ip = 0.9878 ---
# Starting non-linear GS solver
#      1  1.0000E+00  5.0753E-01  5.3417E-03  1.7520E+00 -4.7886E-03  8.4001E+04
#      2  1.0000E+00  4.7041E-01  8.9953E-04  1.7493E+00 -5.1262E-03  8.3891E+04
#      3  1.0000E+00  4.6346E-01  4.6262E-04  1.7478E+00 -5.3670E-03  8.3731E+04
#      4  1.0000E+00  4.6221E-01  2.4093E-04  1.7471E+00 -5.5213E-03  8.3669E+04
#      5  1.0000E+00  4.6205E-01  1.1654E-04  1.7467E+00 -5.6165E-03  8.3669E+04
#      6  1.0000E+00  4.6207E-01  5.4307E-05  1.7466E+00 -5.6740E-03  8.3685E+04
#      7  1.0000E+00  4.6210E-01  2.5189E-05  1.7465E+00 -5.7085E-03  8.3694E+04
#      8  1.0000E+00  4.6212E-01  1.1688E-05  1.7465E+00 -5.7289E-03  8.3700E+04
#      9  1.0000E+00  4.6213E-01  5.4365E-06  1.7465E+00 -5.7410E-03  8.3704E+04
#     10  1.0000E+00  4.6214E-01  2.5485E-06  1.7465E+00 -5.7481E-03  8.3706E+04
#     11  1.0000E+00  4.6214E-01  1.2184E-06  1.7465E+00 -5.7523E-03  8.3708E+04
#     12  1.0000E+00  4.6214E-01  5.8154E-07  1.7465E+00 -5.7547E-03  8.3708E+04
#  Timing:   1.5141350002959371
#    Source:    0.49870799761265516
#    Solve:     0.15836100140586495
#    Boundary:   7.6559996232390404E-003
#    Other:     0.84941000165417790
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.1854e+00
#    Output Ip: 1.2001e+00
#    Mismatch:  0.0038%
# Converged! Optimal scale factor: 0.9878
#
#  >>> Iterating on H-mode equilibrium solution
# Starting non-linear GS solver
#      1  1.0000E+00  4.6214E-01  6.5300E-04  1.7464E+00 -5.7617E-03  8.3797E+04
#      2  1.0000E+00  4.5948E-01  1.1946E-04  1.7462E+00 -5.7731E-03  8.3993E+04
#      3  1.0000E+00  4.5881E-01  3.2286E-05  1.7461E+00 -5.7802E-03  8.4011E+04
#      4  1.0000E+00  4.5862E-01  1.2984E-05  1.7461E+00 -5.7841E-03  8.4015E+04
#      5  1.0000E+00  4.5856E-01  5.9379E-06  1.7460E+00 -5.7862E-03  8.4016E+04
#      6  1.0000E+00  4.5855E-01  2.8686E-06  1.7460E+00 -5.7873E-03  8.4016E+04
#      7  1.0000E+00  4.5854E-01  1.3863E-06  1.7460E+00 -5.7879E-03  8.4015E+04
#      8  1.0000E+00  4.5854E-01  6.5893E-07  1.7460E+00 -5.7883E-03  8.4015E+04
#  Timing:   1.0679469997994602
#    Source:    0.36263599945232272
#    Solve:     0.10930699994787574
#    Boundary:   5.3110001608729362E-003
#    Other:     0.59069300023838878
# Starting non-linear GS solver
#      1  1.0000E+00  4.5854E-01  1.1785E-04  1.7460E+00 -5.7894E-03  8.4025E+04
#      2  1.0000E+00  4.5805E-01  1.8819E-05  1.7460E+00 -5.7913E-03  8.4005E+04
#      3  1.0000E+00  4.5793E-01  5.2631E-06  1.7460E+00 -5.7925E-03  8.4009E+04
#      4  1.0000E+00  4.5789E-01  2.5851E-06  1.7460E+00 -5.7932E-03  8.4024E+04
#      5  1.0000E+00  4.5788E-01  9.7036E-07  1.7459E+00 -5.7935E-03  8.4024E+04
#  Timing:  0.67754899989813566
#    Source:    0.22947399970144033
#    Solve:      6.4941999502480030E-002
#    Boundary:   3.5039996728301048E-003
#    Other:     0.37962900102138519
# Starting non-linear GS solver
#      1  1.0000E+00  4.5788E-01  2.1579E-05  1.7459E+00 -5.7939E-03  8.4026E+04
#      2  1.0000E+00  4.5779E-01  4.0400E-06  1.7459E+00 -5.7943E-03  8.4031E+04
#      3  1.0000E+00  4.5777E-01  7.7553E-07  1.7459E+00 -5.7946E-03  8.4031E+04
#  Timing:  0.44349800003692508
#    Source:    0.15243299957364798
#    Solve:      3.9102000184357166E-002
#    Boundary:   2.3170001804828644E-003
#    Other:     0.24964600009843707
# [fit] ind_scale=0.996601  bs_scale=1.000000  li_proxy=1.061145  (target=1.061145)
# Starting non-linear GS solver
#      1  1.0000E+00 -1.2664E-06  4.1377E-03  1.7458E+00 -5.7925E-03  8.2411E+04
#      2  1.0000E+00 -1.1813E-06  1.3787E-03  1.7449E+00 -5.7675E-03  8.2910E+04
#      3  1.0000E+00 -1.1568E-06  6.1858E-04  1.7443E+00 -5.6989E-03  8.2557E+04
#      4  1.0000E+00 -1.1484E-06  2.9640E-04  1.7440E+00 -5.6219E-03  8.2316E+04
#      5  1.0000E+00 -1.1452E-06  1.4385E-04  1.7438E+00 -5.5543E-03  8.2220E+04
#      6  1.0000E+00 -1.1439E-06  7.2899E-05  1.7437E+00 -5.5011E-03  8.2145E+04
#      7  1.0000E+00 -1.1433E-06  3.5744E-05  1.7436E+00 -5.4618E-03  8.2105E+04
#      8  1.0000E+00 -1.1430E-06  1.7833E-05  1.7436E+00 -5.4336E-03  8.2082E+04
#      9  1.0000E+00 -1.1429E-06  9.1488E-06  1.7436E+00 -5.4139E-03  8.2069E+04
#     10  1.0000E+00 -1.1429E-06  4.8642E-06  1.7436E+00 -5.4004E-03  8.2061E+04
#     11  1.0000E+00 -1.1428E-06  2.7109E-06  1.7436E+00 -5.3911E-03  8.2057E+04
#     12  1.0000E+00 -1.1428E-06  1.5881E-06  1.7436E+00 -5.3848E-03  8.2054E+04
#     13  1.0000E+00 -1.1428E-06  9.7108E-07  1.7436E+00 -5.3805E-03  8.2052E+04
#  Timing:   1.6513709998689592
#    Source:    0.54550900077447295
#    Solve:     0.17809099936857820
#    Boundary:   7.7550010755658150E-003
#    Other:     0.92001599865034223
# Starting non-linear GS solver
#      1  1.0000E+00 -1.1428E-06  5.2810E-04  1.7435E+00 -5.3761E-03  8.1980E+04
#      2  1.0000E+00 -1.1369E-06  9.3126E-05  1.7434E+00 -5.3753E-03  8.2179E+04
#      3  1.0000E+00 -1.1355E-06  2.4043E-05  1.7434E+00 -5.3739E-03  8.2201E+04
#      4  1.0000E+00 -1.1351E-06  9.1715E-06  1.7433E+00 -5.3722E-03  8.2217E+04
#      5  1.0000E+00 -1.1350E-06  3.9729E-06  1.7433E+00 -5.3707E-03  8.2217E+04
#      6  1.0000E+00 -1.1349E-06  2.0871E-06  1.7433E+00 -5.3695E-03  8.2216E+04
#      7  1.0000E+00 -1.1349E-06  1.1429E-06  1.7433E+00 -5.3686E-03  8.2215E+04
#      8  1.0000E+00 -1.1349E-06  6.3255E-07  1.7433E+00 -5.3680E-03  8.2215E+04
#  Timing:   1.0216500000096858
#    Source:    0.33776900125667453
#    Solve:     0.10387999936938286
#    Boundary:   4.8109996132552624E-003
#    Other:     0.57518999977037311
# [li match] target=1.074895
# [li match] iter 0: ind_factor=1.000000  li=1.081478  err=0.006583
# [li match] iter 1: ind_factor=1.050000  li=1.092607  err=0.017712
# Starting non-linear GS solver
#      1  1.0000E+00 -1.1349E-06  8.5892E-04  1.7434E+00 -5.3707E-03  8.2352E+04
#      2  1.0000E+00 -1.1446E-06  1.5047E-04  1.7435E+00 -5.3683E-03  8.1975E+04
#      3  1.0000E+00 -1.1468E-06  4.0893E-05  1.7436E+00 -5.3681E-03  8.1943E+04
#      4  1.0000E+00 -1.1475E-06  1.4898E-05  1.7437E+00 -5.3691E-03  8.1938E+04
#      5  1.0000E+00 -1.1477E-06  6.6540E-06  1.7437E+00 -5.3703E-03  8.1938E+04
#      6  1.0000E+00 -1.1478E-06  3.4952E-06  1.7437E+00 -5.3713E-03  8.1939E+04
#      7  1.0000E+00 -1.1478E-06  1.8887E-06  1.7437E+00 -5.3721E-03  8.1941E+04
#      8  1.0000E+00 -1.1478E-06  1.0256E-06  1.7437E+00 -5.3727E-03  8.1941E+04
#      9  1.0000E+00 -1.1478E-06  5.5206E-07  1.7437E+00 -5.3731E-03  8.1942E+04
#  Timing:   1.1380280000157654
#    Source:    0.37785300053656101
#    Solve:     0.11723000090569258
#    Boundary:   5.6929993443191051E-003
#    Other:     0.63725199922919273
# [li match] iter 2: ind_factor=0.970421  li=1.073542  err=-0.001352
# Starting non-linear GS solver
#      1  1.0000E+00 -1.1478E-06  6.4794E-05  1.7437E+00 -5.3732E-03  8.1934E+04
#      2  1.0000E+00 -1.1471E-06  1.0425E-05  1.7437E+00 -5.3736E-03  8.1961E+04
#      3  1.0000E+00 -1.1469E-06  2.8713E-06  1.7437E+00 -5.3738E-03  8.1963E+04
#      4  1.0000E+00 -1.1469E-06  1.0873E-06  1.7437E+00 -5.3738E-03  8.1964E+04
#      5  1.0000E+00 -1.1469E-06  4.8752E-07  1.7437E+00 -5.3738E-03  8.1964E+04
#  Timing:  0.67528299987316132
#    Source:    0.22629699995741248
#    Solve:      6.4910000190138817E-002
#    Boundary:   3.2540000975131989E-003
#    Other:     0.38082199962809682
# [li match] iter 3: ind_factor=0.976065  li=1.071934  err=-0.002961
# [li match]   secant escaped bracket, bisection -> 0.985211
# Starting non-linear GS solver
#      1  1.0000E+00 -1.1469E-06  1.0351E-04  1.7437E+00 -5.3735E-03  8.1951E+04
#      2  1.0000E+00 -1.1457E-06  1.7215E-05  1.7437E+00 -5.3737E-03  8.1994E+04
#      3  1.0000E+00 -1.1454E-06  4.7171E-06  1.7437E+00 -5.3737E-03  8.1998E+04
#      4  1.0000E+00 -1.1453E-06  1.7743E-06  1.7437E+00 -5.3736E-03  8.1998E+04
#      5  1.0000E+00 -1.1453E-06  8.3554E-07  1.7437E+00 -5.3734E-03  8.1998E+04
#  Timing:  0.70627399999648333
#    Source:    0.23262500017881393
#    Solve:      7.5236000586301088E-002
#    Boundary:   3.9059999398887157E-003
#    Other:     0.39450699929147959
# [li match] iter 4: ind_factor=0.985211  li=1.075923  err=0.001028
# Starting non-linear GS solver
#      1  1.0000E+00 -1.1453E-06  2.6666E-05  1.7437E+00 -5.3734E-03  8.2001E+04
#      2  1.0000E+00 -1.1456E-06  4.3498E-06  1.7437E+00 -5.3732E-03  8.1990E+04
#      3  1.0000E+00 -1.1457E-06  1.1609E-06  1.7437E+00 -5.3731E-03  8.1989E+04
#      4  1.0000E+00 -1.1457E-06  4.1662E-07  1.7437E+00 -5.3731E-03  8.1989E+04
#  Timing:  0.56148299993947148
#    Source:    0.18723500007763505
#    Solve:      5.2332999650388956E-002
#    Boundary:   2.9150000773370266E-003
#    Other:     0.31900000013411045
# [li match] iter 5: ind_factor=0.982853  li=1.075995  err=0.001100
# [li match]   secant escaped bracket, bisection -> 0.977816
# Starting non-linear GS solver
#      1  1.0000E+00 -1.1457E-06  5.7072E-05  1.7437E+00 -5.3733E-03  8.1996E+04
#      2  1.0000E+00 -1.1463E-06  9.6722E-06  1.7437E+00 -5.3731E-03  8.1971E+04
#      3  1.0000E+00 -1.1465E-06  2.6372E-06  1.7437E+00 -5.3731E-03  8.1969E+04
#      4  1.0000E+00 -1.1465E-06  9.8308E-07  1.7437E+00 -5.3732E-03  8.1969E+04
#  Timing:  0.56176900025457144
#    Source:    0.18683199910447001
#    Solve:      5.1969000138342381E-002
#    Boundary:   3.0820001848042011E-003
#    Other:     0.31988600082695484
# [li match] iter 6: ind_factor=0.977816  li=1.073959  err=-0.000936
# [li match] converged at iter 7: ind_factor=0.977816  li=1.073959
# [li match] final li(1)=1.073959  target=1.074895  |err|=0.000936
#
# [Ip match] desired=1200039.5  current=1198160.5  err=-0.1566%
# Starting non-linear GS solver
#      1  1.0000E+00 -1.1466E-06  8.9470E-04  1.7435E+00 -5.3951E-03  8.3012E+04
#      2  1.0000E+00 -1.1338E-06  1.3716E-04  1.7432E+00 -5.4277E-03  8.2998E+04
#      3  1.0000E+00 -1.1313E-06  5.7849E-05  1.7430E+00 -5.4541E-03  8.2970E+04
#      4  1.0000E+00 -1.1308E-06  3.4018E-05  1.7429E+00 -5.4735E-03  8.2959E+04
#      5  1.0000E+00 -1.1307E-06  1.8787E-05  1.7429E+00 -5.4873E-03  8.2960E+04
#      6  1.0000E+00 -1.1308E-06  1.0164E-05  1.7428E+00 -5.4970E-03  8.2961E+04
#      7  1.0000E+00 -1.1308E-06  5.4790E-06  1.7428E+00 -5.5037E-03  8.2963E+04
#      8  1.0000E+00 -1.1308E-06  2.9764E-06  1.7428E+00 -5.5083E-03  8.2964E+04
#      9  1.0000E+00 -1.1308E-06  1.6326E-06  1.7428E+00 -5.5114E-03  8.2965E+04
#     10  1.0000E+00 -1.1308E-06  9.0457E-07  1.7428E+00 -5.5136E-03  8.2965E+04
#  Timing:   1.2661159997805953
#    Source:    0.41819799970835447
#    Solve:     0.13229899993166327
#    Boundary:   5.9060002677142620E-003
#    Other:     0.70971299987286329
# [Ip match] iter 0: Ip_target=1200039.5  Ip=1198160.5
# [Ip match] iter 1: Ip_target=1201921.4  Ip=1216073.1  li=1.074366
# Starting non-linear GS solver
#      1  1.0000E+00 -1.1308E-06  9.1204E-05  1.7428E+00 -5.5129E-03  8.2860E+04
#      2  1.0000E+00 -1.1321E-06  1.4010E-05  1.7429E+00 -5.5106E-03  8.2861E+04
#      3  1.0000E+00 -1.1323E-06  5.8117E-06  1.7429E+00 -5.5086E-03  8.2864E+04
#      4  1.0000E+00 -1.1324E-06  3.3506E-06  1.7429E+00 -5.5071E-03  8.2866E+04
#      5  1.0000E+00 -1.1324E-06  1.8493E-06  1.7429E+00 -5.5060E-03  8.2866E+04
#      6  1.0000E+00 -1.1324E-06  9.9723E-07  1.7429E+00 -5.5053E-03  8.2866E+04
#  Timing:  0.82624199986457825
#    Source:    0.27361800009384751
#    Solve:      8.0978000070899725E-002
#    Boundary:   4.1720005683600903E-003
#    Other:     0.46747399913147092
# [Ip match] iter 2: Ip_target=1200236.9  Ip=1214251.1  li=1.073275
# Starting non-linear GS solver
#      1  1.0000E+00 -1.1324E-06  7.0869E-04  1.7431E+00 -5.4876E-03  8.2038E+04
#      2  1.0000E+00 -1.1425E-06  1.0866E-04  1.7433E+00 -5.4614E-03  8.2049E+04
#      3  1.0000E+00 -1.1445E-06  4.6027E-05  1.7435E+00 -5.4402E-03  8.2070E+04
#      4  1.0000E+00 -1.1449E-06  2.6963E-05  1.7435E+00 -5.4246E-03  8.2077E+04
#      5  1.0000E+00 -1.1450E-06  1.4915E-05  1.7436E+00 -5.4135E-03  8.2079E+04
#      6  1.0000E+00 -1.1449E-06  8.0713E-06  1.7436E+00 -5.4057E-03  8.2078E+04
#      7  1.0000E+00 -1.1449E-06  4.3537E-06  1.7436E+00 -5.4003E-03  8.2077E+04
#      8  1.0000E+00 -1.1449E-06  2.3662E-06  1.7436E+00 -5.3966E-03  8.2076E+04
#      9  1.0000E+00 -1.1449E-06  1.2908E-06  1.7436E+00 -5.3941E-03  8.2075E+04
#     10  1.0000E+00 -1.1449E-06  7.2091E-07  1.7436E+00 -5.3923E-03  8.2075E+04
#  Timing:   1.2707000002264977
#    Source:    0.41716499952599406
#    Solve:     0.13117100019007921
#    Boundary:   5.9910006821155548E-003
#    Other:     0.71637299982830882
# [Ip match] iter 3: Ip_target=1187097.9  Ip=1200034.9  li=1.075517
# [Ip match] converged at iter 4: Ip_target=1187097.9  Ip=1200034.9  li=1.075517
# [final] li(1)=1.075517  Ip=1200034.9  Ip_err=-0.0004%  li_err=0.000623
# File will be saved to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=0.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=0.geqdsk
# Successfully deleted: TkMkr_D3Dlike_Hmode_count=0.geqdsk
#
#  >>> Matching input core j_phi with G-S solution
# Starting non-linear GS solver
#      1  1.0000E+00  8.9729E-01  2.4592E-02  1.7464E+00 -1.2874E-01  3.0917E+05
# WARNING: Candidate X-point and O-point converged to the same location   1.74E+00 -8.69E-02   1.74E+00 -8.69E-02
#      2  1.0000E+00  4.4064E-01  1.5061E-02  1.7427E+00 -8.6946E-02  1.8291E+05
#      3  1.0000E+00  4.4958E-01  7.3118E-03  1.7436E+00 -5.5508E-02  1.1135E+05
#      4  1.0000E+00  4.7014E-01  3.7030E-03  1.7456E+00 -3.4915E-02  9.5571E+04
#      5  1.0000E+00  4.7836E-01  1.7446E-03  1.7472E+00 -2.2614E-02  9.2267E+04
#      6  1.0000E+00  4.8080E-01  9.1714E-04  1.7481E+00 -1.5568E-02  9.0314E+04
#      7  1.0000E+00  4.8138E-01  5.0301E-04  1.7485E+00 -1.1591E-02  8.9210E+04
#      8  1.0000E+00  4.8146E-01  2.7706E-04  1.7488E+00 -9.3565E-03  8.8611E+04
#      9  1.0000E+00  4.8144E-01  1.5423E-04  1.7489E+00 -8.1028E-03  8.8280E+04
#     10  1.0000E+00  4.8140E-01  8.5963E-05  1.7489E+00 -7.3995E-03  8.8093E+04
#     11  1.0000E+00  4.8138E-01  4.8013E-05  1.7490E+00 -7.0048E-03  8.7988E+04
#     12  1.0000E+00  4.8137E-01  2.6853E-05  1.7490E+00 -6.7834E-03  8.7928E+04
#     13  1.0000E+00  4.8136E-01  1.5019E-05  1.7490E+00 -6.6591E-03  8.7895E+04
#     14  1.0000E+00  4.8136E-01  8.4018E-06  1.7490E+00 -6.5894E-03  8.7876E+04
#     15  1.0000E+00  4.8135E-01  4.8589E-06  1.7490E+00 -6.5503E-03  8.7865E+04
#     16  1.0000E+00  4.8135E-01  2.5075E-06  1.7490E+00 -6.5284E-03  8.7866E+04
#     17  1.0000E+00  4.8135E-01  1.4676E-06  1.7490E+00 -6.5160E-03  8.7862E+04
#     18  1.0000E+00  4.8135E-01  8.3634E-07  1.7490E+00 -6.5091E-03  8.7861E+04
#  Timing:   2.2201810004189610
#    Source:    0.71848699916154146
#    Solve:     0.23305400041863322
#    Boundary:   9.9939992651343346E-003
#    Other:      1.2586460015736520
#
#  >>> Finding optimal j_phi scale factor
#
# --- Checking scale_j0 = 1.0000 ---
# Starting non-linear GS solver
#      1  1.0000E+00  4.8135E-01  3.1822E-03  1.7484E+00 -6.5517E-03  8.8374E+04
#      2  1.0000E+00  4.6686E-01  4.9584E-04  1.7475E+00 -6.6244E-03  8.9132E+04
#      3  1.0000E+00  4.6344E-01  1.7424E-04  1.7470E+00 -6.6703E-03  8.9247E+04
#      4  1.0000E+00  4.6249E-01  7.8123E-05  1.7467E+00 -6.6960E-03  8.9275E+04
#      5  1.0000E+00  4.6220E-01  3.6368E-05  1.7466E+00 -6.7102E-03  8.9283E+04
#      6  1.0000E+00  4.6211E-01  1.6783E-05  1.7465E+00 -6.7180E-03  8.9286E+04
#      7  1.0000E+00  4.6208E-01  7.9943E-06  1.7465E+00 -6.7224E-03  8.9287E+04
#      8  1.0000E+00  4.6207E-01  3.7704E-06  1.7465E+00 -6.7249E-03  8.9287E+04
#      9  1.0000E+00  4.6207E-01  1.7774E-06  1.7465E+00 -6.7263E-03  8.9287E+04
#     10  1.0000E+00  4.6207E-01  8.2463E-07  1.7464E+00 -6.7271E-03  8.9288E+04
#  Timing:   1.2992239999584854
#    Source:    0.44661699980497360
#    Solve:     0.12962799938395619
#    Boundary:   5.7920012623071671E-003
#    Other:     0.71718699950724840
#    Input j_0:  1.2330e+06
#    Output j_0: 1.3016e+06
#    Mismatch:  5.275%
#
# --- Checking scale_j0 = 1.2000 ---
# Starting non-linear GS solver
#      1  1.0000E+00  4.6207E-01  1.7777E-03  1.7461E+00 -6.7453E-03  8.9188E+04
#      2  1.0000E+00  4.5404E-01  3.0195E-04  1.7457E+00 -6.7778E-03  8.9602E+04
#      3  1.0000E+00  4.5206E-01  8.8845E-05  1.7454E+00 -6.7976E-03  8.9652E+04
#      4  1.0000E+00  4.5151E-01  3.6494E-05  1.7452E+00 -6.8080E-03  8.9643E+04
#      5  1.0000E+00  4.5134E-01  1.7433E-05  1.7452E+00 -6.8133E-03  8.9643E+04
#      6  1.0000E+00  4.5129E-01  8.2353E-06  1.7451E+00 -6.8161E-03  8.9643E+04
#      7  1.0000E+00  4.5127E-01  4.0364E-06  1.7451E+00 -6.8176E-03  8.9643E+04
#      8  1.0000E+00  4.5127E-01  1.9443E-06  1.7451E+00 -6.8184E-03  8.9642E+04
#      9  1.0000E+00  4.5127E-01  9.4363E-07  1.7451E+00 -6.8188E-03  8.9642E+04
#  Timing:   1.1431390000507236
#    Source:    0.38427700148895383
#    Solve:     0.11668299976736307
#    Boundary:   5.4760007187724113E-003
#    Other:     0.63670299807563424
#    Input j_0:  1.4617e+06
#    Output j_0: 1.3423e+06
#    Mismatch:  8.900%
# --- Optimization Iteration 1 ---
#
# --- Checking scale_j0 = 1.0730 ---
# Starting non-linear GS solver
#      1  1.0000E+00  4.5127E-01  1.0650E-03  1.7453E+00 -6.8110E-03  8.9818E+04
#      2  1.0000E+00  4.5607E-01  1.8457E-04  1.7456E+00 -6.7926E-03  8.9560E+04
#      3  1.0000E+00  4.5726E-01  5.4939E-05  1.7457E+00 -6.7810E-03  8.9531E+04
#      4  1.0000E+00  4.5759E-01  2.3646E-05  1.7458E+00 -6.7748E-03  8.9525E+04
#      5  1.0000E+00  4.5769E-01  1.1927E-05  1.7459E+00 -6.7716E-03  8.9524E+04
#      6  1.0000E+00  4.5772E-01  6.9756E-06  1.7459E+00 -6.7699E-03  8.9512E+04
#      7  1.0000E+00  4.5773E-01  2.7925E-06  1.7459E+00 -6.7690E-03  8.9512E+04
#      8  1.0000E+00  4.5773E-01  1.2361E-06  1.7459E+00 -6.7685E-03  8.9512E+04
#      9  1.0000E+00  4.5773E-01  5.7122E-07  1.7459E+00 -6.7682E-03  8.9512E+04
#  Timing:   1.1663120002485812
#    Source:    0.38613900123164058
#    Solve:     0.11640299996361136
#    Boundary:   5.5610002018511295E-003
#    Other:     0.65820899885147810
#    Input j_0:  1.3165e+06
#    Output j_0: 1.3177e+06
#    Mismatch:  0.095%
# Converged! Optimal scale factor: 1.0730
#
#  >>> Finding optimal Ip scale factor
#
# --- Checking scale_Ip = 1.0000 ---
# Starting non-linear GS solver
#      1  1.0000E+00  4.5773E-01  2.7031E-07  1.7459E+00 -6.7681E-03  8.9512E+04
#  Timing:  0.23573000030592084
#    Source:     7.9583999700844288E-002
#    Solve:      1.3513999991118908E-002
#    Boundary:   1.3790000230073929E-003
#    Other:     0.14125300059095025
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.2000e+00
#    Output Ip: 1.2157e+00
#    Mismatch:  1.3059%
#
# --- Checking scale_Ip = 0.9000 ---
# Starting non-linear GS solver
#      1  1.0000E+00  4.5773E-01  5.7972E-03  1.7483E+00 -6.4977E-03  8.1308E+04
#      2  1.0000E+00  4.9790E-01  8.8702E-04  1.7515E+00 -6.0882E-03  8.1193E+04
#      3  1.0000E+00  5.0699E-01  5.0535E-04  1.7533E+00 -5.7837E-03  8.1214E+04
#      4  1.0000E+00  5.0875E-01  2.7152E-04  1.7542E+00 -5.5870E-03  8.1205E+04
#      5  1.0000E+00  5.0900E-01  1.3212E-04  1.7546E+00 -5.4657E-03  8.1190E+04
#      6  1.0000E+00  5.0900E-01  6.2210E-05  1.7548E+00 -5.3923E-03  8.1171E+04
#      7  1.0000E+00  5.0897E-01  2.8956E-05  1.7549E+00 -5.3485E-03  8.1159E+04
#      8  1.0000E+00  5.0895E-01  1.3447E-05  1.7549E+00 -5.3225E-03  8.1151E+04
#      9  1.0000E+00  5.0894E-01  6.2419E-06  1.7549E+00 -5.3072E-03  8.1148E+04
#     10  1.0000E+00  5.0894E-01  2.9435E-06  1.7549E+00 -5.2982E-03  8.1145E+04
#     11  1.0000E+00  5.0894E-01  1.3844E-06  1.7549E+00 -5.2929E-03  8.1144E+04
#     12  1.0000E+00  5.0893E-01  6.9161E-07  1.7549E+00 -5.2899E-03  8.1143E+04
#  Timing:   1.5161660001613200
#    Source:    0.49865300022065639
#    Solve:     0.16229800041764975
#    Boundary:   7.3310001753270626E-003
#    Other:     0.84788399934768677
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.0800e+00
#    Output Ip: 1.0842e+00
#    Mismatch:  9.6533%
# --- Optimization Iteration 1 ---
#
# --- Checking scale_Ip = 0.9881 ---
# Starting non-linear GS solver
#      1  1.0000E+00  5.0893E-01  5.1788E-03  1.7525E+00 -5.5615E-03  8.8405E+04
#      2  1.0000E+00  4.7159E-01  7.8995E-04  1.7497E+00 -5.9256E-03  8.8474E+04
#      3  1.0000E+00  4.6460E-01  4.5801E-04  1.7482E+00 -6.1863E-03  8.8418E+04
#      4  1.0000E+00  4.6334E-01  2.4352E-04  1.7474E+00 -6.3540E-03  8.8455E+04
#      5  1.0000E+00  4.6318E-01  1.1853E-04  1.7471E+00 -6.4577E-03  8.8486E+04
#      6  1.0000E+00  4.6320E-01  5.5431E-05  1.7470E+00 -6.5206E-03  8.8503E+04
#      7  1.0000E+00  4.6323E-01  2.5835E-05  1.7469E+00 -6.5583E-03  8.8515E+04
#      8  1.0000E+00  4.6325E-01  1.2057E-05  1.7469E+00 -6.5807E-03  8.8522E+04
#      9  1.0000E+00  4.6326E-01  5.6309E-06  1.7468E+00 -6.5940E-03  8.8527E+04
#     10  1.0000E+00  4.6327E-01  2.6576E-06  1.7468E+00 -6.6018E-03  8.8530E+04
#     11  1.0000E+00  4.6327E-01  1.2773E-06  1.7468E+00 -6.6064E-03  8.8531E+04
#     12  1.0000E+00  4.6327E-01  6.2349E-07  1.7468E+00 -6.6091E-03  8.8532E+04
#  Timing:   1.5054770000278950
#    Source:    0.50082399975508451
#    Solve:     0.15540500031784177
#    Boundary:   7.7629997394979000E-003
#    Other:     0.84148500021547079
#    Input Ip target:  1.2000e+00
#    Trial Ip target:  1.1857e+00
#    Output Ip: 1.2001e+00
#    Mismatch:  0.0048%
# Converged! Optimal scale factor: 0.9881
#
#  >>> Iterating on H-mode equilibrium solution
# Starting non-linear GS solver
#      1  1.0000E+00  4.6327E-01  6.0056E-04  1.7467E+00 -6.6165E-03  8.8500E+04
#      2  1.0000E+00  4.6058E-01  1.0902E-04  1.7466E+00 -6.6288E-03  8.8598E+04
#      3  1.0000E+00  4.5991E-01  3.4190E-05  1.7465E+00 -6.6365E-03  8.8612E+04
#      4  1.0000E+00  4.5972E-01  1.4324E-05  1.7464E+00 -6.6407E-03  8.8628E+04
#      5  1.0000E+00  4.5967E-01  6.6795E-06  1.7464E+00 -6.6429E-03  8.8629E+04
#      6  1.0000E+00  4.5965E-01  3.1716E-06  1.7464E+00 -6.6441E-03  8.8634E+04
#      7  1.0000E+00  4.5965E-01  1.4438E-06  1.7464E+00 -6.6448E-03  8.8634E+04
#      8  1.0000E+00  4.5964E-01  6.8440E-07  1.7464E+00 -6.6452E-03  8.8634E+04
#  Timing:   1.0594680001959205
#    Source:    0.34447700018063188
#    Solve:     0.10413000034168363
#    Boundary:   4.9020005390048027E-003
#    Other:     0.60595899913460016
# Starting non-linear GS solver
#      1  1.0000E+00  4.5964E-01  1.0803E-04  1.7464E+00 -6.6463E-03  8.8621E+04
#      2  1.0000E+00  4.5915E-01  2.0148E-05  1.7463E+00 -6.6484E-03  8.8652E+04
#      3  1.0000E+00  4.5903E-01  5.9195E-06  1.7463E+00 -6.6497E-03  8.8657E+04
#      4  1.0000E+00  4.5900E-01  3.4594E-06  1.7463E+00 -6.6504E-03  8.8638E+04
#      5  1.0000E+00  4.5899E-01  1.2010E-06  1.7463E+00 -6.6508E-03  8.8638E+04
#      6  1.0000E+00  4.5898E-01  5.2938E-07  1.7463E+00 -6.6510E-03  8.8638E+04
#  Timing:  0.79307899996638298
#    Source:    0.26701300032436848
#    Solve:      7.7763000503182411E-002
#    Boundary:   3.8419994525611401E-003
#    Other:     0.44446099968627095
# Starting non-linear GS solver
#      1  1.0000E+00  4.5898E-01  1.9710E-05  1.7463E+00 -6.6513E-03  8.8636E+04
#      2  1.0000E+00  4.5889E-01  3.5285E-06  1.7463E+00 -6.6517E-03  8.8641E+04
#      3  1.0000E+00  4.5887E-01  1.3319E-06  1.7463E+00 -6.6519E-03  8.8643E+04
#      4  1.0000E+00  4.5886E-01  5.0494E-07  1.7463E+00 -6.6521E-03  8.8644E+04
#  Timing:  0.56091600004583597
#    Source:    0.19070900045335293
#    Solve:      5.1497000269591808E-002
#    Boundary:   2.5859996676445007E-003
#    Other:     0.31612399965524673
# [fit] ind_scale=1.012040  bs_scale=1.000000  li_proxy=0.919943  (target=0.919943)
# Starting non-linear GS solver
#      1  1.0000E+00 -1.2664E-06  2.8420E-03  1.7463E+00 -6.6367E-03  8.7416E+04
#      2  1.0000E+00 -1.2824E-06  7.7503E-04  1.7467E+00 -6.5678E-03  8.6866E+04
#      3  1.0000E+00 -1.2873E-06  2.7018E-04  1.7470E+00 -6.5089E-03  8.6885E+04
#      4  1.0000E+00 -1.2890E-06  1.0384E-04  1.7471E+00 -6.4682E-03  8.6800E+04
#      5  1.0000E+00 -1.2896E-06  3.9811E-05  1.7472E+00 -6.4423E-03  8.6797E+04
#      6  1.0000E+00 -1.2898E-06  1.5881E-05  1.7473E+00 -6.4264E-03  8.6794E+04
#      7  1.0000E+00 -1.2899E-06  6.9668E-06  1.7473E+00 -6.4167E-03  8.6793E+04
#      8  1.0000E+00 -1.2899E-06  3.1524E-06  1.7473E+00 -6.4109E-03  8.6792E+04
#      9  1.0000E+00 -1.2899E-06  1.4638E-06  1.7473E+00 -6.4075E-03  8.6791E+04
#     10  1.0000E+00 -1.2899E-06  7.0228E-07  1.7473E+00 -6.4054E-03  8.6790E+04
#  Timing:   1.2806190000846982
#    Source:    0.42165199993178248
#    Solve:     0.13034199969843030
#    Boundary:   5.9110000729560852E-003
#    Other:     0.72271400038152933
# Starting non-linear GS solver
#      1  1.0000E+00 -1.2899E-06  4.4009E-04  1.7472E+00 -6.4089E-03  8.6751E+04
#      2  1.0000E+00 -1.2841E-06  4.9709E-05  1.7471E+00 -6.4174E-03  8.6890E+04
#      3  1.0000E+00 -1.2828E-06  4.1900E-05  1.7470E+00 -6.4219E-03  8.6869E+04
#      4  1.0000E+00 -1.2825E-06  1.6508E-05  1.7470E+00 -6.4239E-03  8.6884E+04
#      5  1.0000E+00 -1.2823E-06  1.1563E-05  1.7470E+00 -6.4248E-03  8.6879E+04
#      6  1.0000E+00 -1.2823E-06  3.0266E-06  1.7470E+00 -6.4252E-03  8.6878E+04
#      7  1.0000E+00 -1.2823E-06  1.1040E-06  1.7470E+00 -6.4253E-03  8.6878E+04
#      8  1.0000E+00 -1.2823E-06  4.7402E-07  1.7469E+00 -6.4254E-03  8.6877E+04
#  Timing:   1.0459199999459088
#    Source:    0.35014200024306774
#    Solve:     0.10391299938783050
#    Boundary:   5.1400004886090755E-003
#    Other:     0.58672499982640147
# [li match] target=0.904842
# [li match] iter 0: ind_factor=1.000000  li=0.913036  err=0.008194
# [li match] iter 1: ind_factor=1.050000  li=0.921548  err=0.016706
# Starting non-linear GS solver
#      1  1.0000E+00 -1.2823E-06  8.9740E-04  1.7471E+00 -6.4164E-03  8.6979E+04
#      2  1.0000E+00 -1.2941E-06  1.0438E-04  1.7474E+00 -6.3968E-03  8.6701E+04
#      3  1.0000E+00 -1.2968E-06  4.6758E-05  1.7475E+00 -6.3861E-03  8.6678E+04
#      4  1.0000E+00 -1.2975E-06  2.1984E-05  1.7476E+00 -6.3810E-03  8.6701E+04
#      5  1.0000E+00 -1.2978E-06  2.0497E-05  1.7476E+00 -6.3786E-03  8.6651E+04
#      6  1.0000E+00 -1.2978E-06  6.0762E-06  1.7477E+00 -6.3775E-03  8.6651E+04
#      7  1.0000E+00 -1.2979E-06  3.0301E-06  1.7477E+00 -6.3769E-03  8.6651E+04
#      8  1.0000E+00 -1.2979E-06  2.1581E-06  1.7477E+00 -6.3766E-03  8.6653E+04
#      9  1.0000E+00 -1.2979E-06  6.5132E-07  1.7477E+00 -6.3765E-03  8.6653E+04
#  Timing:   1.1527979997918010
#    Source:    0.38031800044700503
#    Solve:     0.11592500004917383
#    Boundary:   5.6229992769658566E-003
#    Other:     0.65093200001865625
# [li match] iter 2: ind_factor=0.951870  li=0.901462  err=-0.003380
# Starting non-linear GS solver
#      1  1.0000E+00 -1.2979E-06  1.6128E-04  1.7476E+00 -6.3783E-03  8.6644E+04
#      2  1.0000E+00 -1.2958E-06  2.5589E-05  1.7476E+00 -6.3819E-03  8.6739E+04
#      3  1.0000E+00 -1.2953E-06  8.6711E-06  1.7476E+00 -6.3839E-03  8.6741E+04
#      4  1.0000E+00 -1.2951E-06  3.8638E-06  1.7475E+00 -6.3849E-03  8.6741E+04
#      5  1.0000E+00 -1.2951E-06  1.7121E-06  1.7475E+00 -6.3853E-03  8.6741E+04
#      6  1.0000E+00 -1.2951E-06  7.6748E-07  1.7475E+00 -6.3856E-03  8.6741E+04
#  Timing:  0.80766199994832277
#    Source:    0.26758900051936507
#    Solve:      7.8157999552786350E-002
#    Boundary:   3.6910003982484341E-003
#    Other:     0.45822399947792292
# [li match] iter 3: ind_factor=0.968383  li=0.905764  err=0.000923
# [li match] converged at iter 4: ind_factor=0.968383  li=0.905764
# [li match] final li(1)=0.905764  target=0.904842  |err|=0.000923
#
# [Ip match] desired=1200045.6  current=1201051.6  err=+0.0838%
# Starting non-linear GS solver
#      1  1.0000E+00 -1.2951E-06  6.5308E-04  1.7473E+00 -6.4172E-03  8.7623E+04
#      2  1.0000E+00 -1.2835E-06  9.7200E-05  1.7469E+00 -6.4595E-03  8.7621E+04
#      3  1.0000E+00 -1.2811E-06  4.2556E-05  1.7468E+00 -6.4882E-03  8.7560E+04
#      4  1.0000E+00 -1.2807E-06  2.5206E-05  1.7467E+00 -6.5060E-03  8.7636E+04
#      5  1.0000E+00 -1.2806E-06  1.3077E-05  1.7467E+00 -6.5168E-03  8.7638E+04
#      6  1.0000E+00 -1.2806E-06  6.2047E-06  1.7467E+00 -6.5233E-03  8.7639E+04
#      7  1.0000E+00 -1.2807E-06  2.9428E-06  1.7466E+00 -6.5273E-03  8.7640E+04
#      8  1.0000E+00 -1.2807E-06  1.3980E-06  1.7466E+00 -6.5297E-03  8.7641E+04
#      9  1.0000E+00 -1.2807E-06  6.6661E-07  1.7466E+00 -6.5311E-03  8.7642E+04
#  Timing:   1.1623239996843040
#    Source:    0.38248300040140748
#    Solve:     0.11638000048696995
#    Boundary:   5.3719994612038136E-003
#    Other:     0.65808899933472276
# [Ip match] iter 0: Ip_target=1200045.6  Ip=1201051.6
# [Ip match] iter 1: Ip_target=1199040.5  Ip=1215561.1  li=0.904385
# Starting non-linear GS solver
#      1  1.0000E+00 -1.2807E-06  5.2462E-05  1.7466E+00 -6.5344E-03  8.7713E+04
#      2  1.0000E+00 -1.2797E-06  7.7734E-06  1.7466E+00 -6.5383E-03  8.7713E+04
#      3  1.0000E+00 -1.2796E-06  3.8941E-06  1.7466E+00 -6.5409E-03  8.7713E+04
#      4  1.0000E+00 -1.2795E-06  2.1606E-06  1.7466E+00 -6.5425E-03  8.7713E+04
#      5  1.0000E+00 -1.2795E-06  1.0795E-06  1.7466E+00 -6.5435E-03  8.7713E+04
#      6  1.0000E+00 -1.2795E-06  5.2222E-07  1.7466E+00 -6.5441E-03  8.7713E+04
#  Timing:  0.80334899993613362
#    Source:    0.26674100058153272
#    Solve:      7.7144999522715807E-002
#    Boundary:   4.1530006565153599E-003
#    Other:     0.45530999917536974
# [Ip match] iter 2: Ip_target=1200115.3  Ip=1216737.7  li=0.905184
# Starting non-linear GS solver
#      1  1.0000E+00 -1.2795E-06  7.4844E-04  1.7469E+00 -6.5087E-03  8.6701E+04
#      2  1.0000E+00 -1.2928E-06  1.1079E-04  1.7472E+00 -6.4605E-03  8.6703E+04
#      3  1.0000E+00 -1.2955E-06  4.8208E-05  1.7474E+00 -6.4275E-03  8.6690E+04
#      4  1.0000E+00 -1.2960E-06  2.8324E-05  1.7475E+00 -6.4071E-03  8.6690E+04
#      5  1.0000E+00 -1.2961E-06  1.4741E-05  1.7476E+00 -6.3947E-03  8.6688E+04
#      6  1.0000E+00 -1.2961E-06  7.1227E-06  1.7476E+00 -6.3872E-03  8.6686E+04
#      7  1.0000E+00 -1.2961E-06  3.4122E-06  1.7476E+00 -6.3826E-03  8.6685E+04
#      8  1.0000E+00 -1.2961E-06  1.6150E-06  1.7476E+00 -6.3799E-03  8.6684E+04
#      9  1.0000E+00 -1.2961E-06  5.9666E-07  1.7476E+00 -6.3782E-03  8.6683E+04
#  Timing:   1.1753179999068379
#    Source:    0.39010800002142787
#    Solve:     0.11755800060927868
#    Boundary:   5.2910000085830688E-003
#    Other:     0.66236099926754832
# [Ip match] iter 3: Ip_target=1184867.2  Ip=1200085.6  li=0.906016
# [Ip match] converged at iter 4: Ip_target=1184867.2  Ip=1200085.6  li=0.906016
# [final] li(1)=0.906016  Ip=1200085.6  Ip_err=+0.0033%  li_err=0.001175
# File will be saved to: /Users/danielburgess/Desktop/plasma/bouquet/examples/D3D-like/TkMkr_D3Dlike_Hmode_count=0.geqdsk
# Saving gEQDSK: TkMkr_D3Dlike_Hmode_count=0.geqdsk
# Successfully deleted: TkMkr_D3Dlike_Hmode_count=0.geqdsk

# %%
# --- Run overview ---
plot_tokamaker_comparison(mygs, all_results, plot_idx=0)
# Out:
# --- Summary for TkMkr_D3Dlike_Hmode_BSamp=1.0.geqdsk ---
#   bs_factor_final : 1.000000
#   li(1) achieved  : 1.075517
#   j_phi RMS error : 22707.02 A/m^2  (0.0227 MA/m^2)
#   eqdsk Ip        : 1200040 A
#   TokaMaker Ip    : 1200035 A  (-0.000%)
#   Boundary dev.   : max=24.40 mm  RMS=3.95 mm

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
import time

# RUN BLOCK







for i,geqdsk in enumerate(geqdsks):

    mygs.set_targets(Ip = abs(eqdsk['ip']), pax=eqdsk['pres'][0])

    isoflux_pts = eqdsk['rzout'].copy()
    weights = np.ones(90)*100.
    weights = weights[0:]
    mygs.set_isoflux(isoflux_pts,weights=weights)

    print('starting with')
    print(geqdsk)
        
    pcount = 0

    input_jinductive = 
    
    results = solve_with_bootstrap(mygs,
                               ne,
                               te,
                               ni,
                               ti,
                               Zeff,
                               abs(eqdsk['ip']),
                               input_jinductive,
                               scale_jBS=1.0,
                               isolate_edge_jBS=True,
                               diagnostic_plots=False
                              )
    

    
    new_jphi = results['total_j_phi']
    input_j_phi = new_jphi
    spike_profile = results['isolated_j_BS']
    initial_j_BS = results['j_BS']
    #dict_keys(['total_j_phi', 'j_BS', 'j_inductive', 'isolated_j_BS'])
    
    eq_stats = mygs.get_stats(li_normalization='std',lcfs_pad=pad_psi)
    li1 = eq_stats['l_i']
    eq_stats = mygs.get_stats(li_normalization='iter',lcfs_pad=pad_psi)
    li3 = eq_stats['l_i']
    


    sigma_ne = 0.2*np.ones_like(ne)*ne
    sigma_te = 0.2*np.ones_like(te)*te
    sigma_ni = 0.3*np.ones_like(ni)*ni
    sigma_ti = 0.3*np.ones_like(ti)*ti
    sigma_jphi = 0.2*np.ones_like(new_jphi)*new_jphi
    
    n_ls = 0.5
    t_ls = 0.4
    j_ls = 0.4

    ### GPR FUNC
    n_equils = 15    
    diagnostics = generate_perturbed_equilibria(     
                                        mygs,
                                        master_psi,
                                        n_equils,
                                        header,
                                        input_j_phi,
                                        ne,
                                        te,
                                        ni,
                                        ti,
                                        sigma_ne,
                                        sigma_te,
                                        sigma_ni,
                                        sigma_ti,
                                        sigma_jphi,
                                        n_ls,
                                        t_ls,
                                        j_ls,
                                        abs(eqdsk['ip']),
                                        l_i_target,
                                        Zeff,
                                        input_jinductive=input_jinductive, # needed if recalculate_j_BS=True
                                        l_i_tolerance=0.03, # match l_i to within 0.03 units of l_i
                                        l_i_proxy_threshold=1.0, # [%]
                                        psi_pad=1e-3,
                                        constrain_sawteeth=True,
                                        recalculate_j_BS=True,
                                        diagnostic_plots=False,
                                        baseline=amp,
                                    )

# %%
plot_family(header, scan_value=2.0, mode="all")

# %% [markdown]
# ### Plot equilibrium
# Flux surfaces of the computed equilibrium can be plotted using the \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.plot_psi "plot_psi()" method. The additional plotting methods \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.plot_machine "plot_machine()" and \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.plot_constraints "plot_constraints()" are also used to show context and other information. Each method has a large number of optional arguments for formatting and other options.

# %%
fig, ax = plt.subplots(1,1,figsize=(10,8))
mygs.plot_machine(fig,ax,coil_colormap='seismic',coil_symmap=True,coil_scale=1.E-6,coil_clabel=r'$I_C$ [MA]')
mygs.plot_psi(fig,ax,vacuum_nlevels=4)
_ = ax.plot(eqdsk['rzout'][:,0], eqdsk['rzout'][:,1],'r--')
ax.set_xlabel('R [m]')
ax.set_ylabel('Z [m]')

# %% [markdown]
# ### Print equilibrium information and coil currents
# Basic parameters can be displayed using the \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.print_info "print_info()" method. For access to these quantities as variables instead the \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.get_stats "get_stats()" can be used.
#
# The final coil currents can also be retrieved using the \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.get_coil_currents "get_coil_currents()" method.  Here, we plot the deviation of the TokaMaker currents from the desired target currents set above.

# %%
mygs.print_info()

currents, currentmap = mygs.get_coil_currents()
err = []
keys = []
for key in mygs.coil_sets:
    try:
        i = mygs.coil_sets[key]['id']
        if key.startswith('A') or key.startswith('B'):
            continue
        err.append(100*(target_currents[key]-currents[i])/max(1.E3,abs(target_currents[key])))
        keys.append(key)
        print('  {0:10} {1:10.2F} {2:10.2F} {3:10.2F}'.format(key+":",currents[i]/1.E3,target_currents[key]/1.E3,100*abs((target_currents[key]-currents[i]))/max(1.E3,abs(target_currents[key]))))
    except:
        pass
#plt.plot(range(len(keys)),err)
#plt.grid(True)
#_ =plt.xticks(range(len(keys)), keys, rotation='vertical')

# %% [markdown]
# ### Retrieve profile information
#
# Here, we use \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.get_profiles "get_profiles()" and \ref OpenFUSIONToolkit.TokaMaker.TokaMaker.get_q "get_q()"to obtain the profiles of our equilibrium and compare them to the profiles of the target gEQDSK.

# %%
psi,f,fp,p,pp = mygs.get_profiles(npsi=eqdsk['nr'],psi_pad=pad_psi)
psi_q,qvals,ravgs,dl,rbounds,zbounds = mygs.get_q(npsi=eqdsk['nr'],psi_pad=pad_psi)
fig, ax = plt.subplots(3,1,sharex=True)
psi_eqdsk = np.linspace(0.0,1.0,eqdsk['nr'])
psi_sample = np.linspace(0.0,1.0,10)
# Plot F*F'
ax[0].plot(psi,f*fp)
ax[0].plot(psi_eqdsk,-eqdsk['ffprim'],'+')
ax[0].set_ylabel("FF'")
# Plot P'
ax[1].plot(psi,pp)
ax[1].plot(psi_eqdsk,-eqdsk['pprime'],'+')
ax[1].set_ylabel("P'")
# Plot q
ax[2].plot(psi_q,qvals)
ax[2].plot(psi_eqdsk,eqdsk['qpsi'],'+')
ax[2].set_ylabel("q")
_ = ax[-1].set_xlabel(r"$\hat{\psi}$")

# %%
fig, ax = plt.subplots(3,1,sharex=True)
psi_eqdsk = np.linspace(0.0,1.0,eqdsk['nr'])
psi_sample = np.linspace(0.0,1.0,10)
# Plot F*F'
ax[0].plot(psi,f*fp,label='TokaMaker')
ax[0].plot(psi_eqdsk,-eqdsk['ffprim'],label='EFIT')
ax[0].set_ylabel("FF'")
ax[0].legend(loc='lower left')
# Plot P'
ax[1].plot(psi,pp)
ax[1].plot(psi_eqdsk,-eqdsk['pprime'])
ax[1].set_ylabel("P'")
# Plot q
ax[2].plot(psi_q,qvals)
ax[2].plot(psi_eqdsk,eqdsk['qpsi'])
ax[2].set_ylabel("q")
_ = ax[-1].set_xlabel(r"$\hat{\psi}$")

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,8))
mygs.plot_machine(fig,ax,coil_colormap=None)
curr = mygs.get_delstar_curr(mygs.get_psi(False))
mask = (mygs.reg == 1)
vmax = (abs(curr[mygs.lc[mask]])).max()
clf = ax.tricontourf(mygs.r[:,0],mygs.r[:,1],mygs.lc[mask],curr,40,cmap='seismic',vmin=-vmax,vmax=vmax)
fig.colorbar(clf,label='j$_{phi}$ [A]')
ax.set_xlabel('R [m]')
ax.set_ylabel('Z [m]')
