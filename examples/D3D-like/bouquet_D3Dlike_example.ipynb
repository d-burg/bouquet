# %% [markdown]
# # Bouquet + TokaMaker — D3D-like H-mode perturbed-equilibrium example
#
# A **fully self-contained, non-proprietary** demonstration of the `bouquet`
# workflow: reconstruct a DIII-D-like H-mode baseline, then generate a family
# ("bouquet") of perturbed equilibria from synthetic kinetic-profile
# uncertainties.
#
# All inputs ship with the repo:
#
# | file | role |
# |---|---|
# | `D3Dlike_Hmode_baseline.geqdsk` | magnetic equilibrium (COCOS 1, Ip>0, Bt<0) |
# | `D3Dlike_Hmode_baseline.peqdsk` | generic D3D-like kinetic profiles |
# | `DIIID_mesh.h5` | TokaMaker DIII-D mesh |
#
# Uncertainties come from `bouquet.synthetic_ida_sigma` (a sine-basis,
# IDA-calibrated *fractional* envelope) — no proprietary IDA data required.
#
# > **Note on the baseline:** `D3Dlike_Hmode_baseline.geqdsk` was derived from a
# > real DIII-D shape but solved with generic profiles + free coils, so it is a
# > synthetic, shareable equilibrium (see `D3Dlike_Hmode_baseline_RECIPE.md`).
#
# > **Why filter?** The bouquet explores profile uncertainty *freely*, so by design some draws drive the shaping coils past the DIII-D ±2 % current-measurement spec — those equilibria are not realizable on the machine — and the boundary can wander further than a given study wants. Before using the family downstream you **filter** it down to the in-spec subset (§9).

# %% [markdown]
# ## 1. Imports

# %%
import sys, os

# --- TEMPORARY path-insert ----------------------------------------------------
# Until the updated backend is merged into a single shipped `bouquet`, run
# against the development worktree.  Remove this block once merged.
_DEV_BOUQUET = '/Users/danielburgess/Desktop/plasma/bouquet_coil_bounds'
sys.path[:] = [p for p in sys.path if not p.rstrip('/').endswith('/plasma/bouquet')
               and not p.rstrip('/').endswith('/plasma/bouquet_phantom_vsc')]
if _DEV_BOUQUET not in sys.path:
    sys.path.insert(0, _DEV_BOUQUET)
for _m in [m for m in list(sys.modules) if m == 'bouquet' or m.startswith('bouquet.')]:
    del sys.modules[_m]
# ------------------------------------------------------------------------------

import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# --- TokaMaker ---
_OFT = '/Users/danielburgess/Desktop/plasma/OpenFUSIONToolkit/build_release'
sys.path.append(os.path.join(_OFT, 'python'))
from OpenFUSIONToolkit import OFT_env
from OpenFUSIONToolkit.TokaMaker import TokaMaker
from OpenFUSIONToolkit.TokaMaker.meshing import load_gs_mesh
from OpenFUSIONToolkit.TokaMaker.util import create_power_flux_fun

# --- Bouquet ---
import bouquet
assert 'bouquet_coil_bounds' in bouquet.__file__, f"wrong bouquet: {bouquet.__file__}"
from bouquet import (
    read_geqdsk, reconstruct_equilibrium, generate_bouquet,
    initialize_equilibrium_database, store_equilibrium,
    synthetic_ida_sigma,
    plot_bouquet, plot_traces, plot_boundary_point_traces,
    plot_geqdsk_bouquet, plot_pfile_bouquet, plot_coil_currents,
    plot_tokamaker_comparison, GEQDSKEquilibrium,
)
from bouquet import (filter_coil_currents, filter_boundaries,
                     select_indices, export_filtered)
from bouquet.io.pfile import read_pfile
print("bouquet:", bouquet.__file__)
# Out:
# bouquet: /Users/danielburgess/Desktop/plasma/bouquet_coil_bounds/bouquet/__init__.py

# %% [markdown]
# ## 2. Configuration — **all knobs live here**
#
# Every tunable parameter (paths, seed, `generate_bouquet` kwargs, backend env
# gates) is set in this one cell.  Headless diagnostic runs execute this exact
# notebook and may override only `N_EQUILS` / `HEADER` via environment variables
# — nothing else differs between an interactive run and a scripted run.

# %%
# =====================================================================
#  RUN MODE  —  top-level toggle
# =====================================================================
# REGENERATE = True  : reconstruct the baseline with TokaMaker and generate
#                      the bouquet from scratch (minutes); overwrites <header>.h5.
# REGENERATE = False : skip straight to the plots + filtering using the
#                      existing golden draws in <header>.h5 (seconds).
REGENERATE = True

# ---- input files (all shipped in this directory) ----
GEQ  = 'D3Dlike_Hmode_baseline.geqdsk'
PF   = 'D3Dlike_Hmode_baseline.peqdsk'
MESH = 'DIIID_mesh.h5'

# ---- run controls (plain scalars) ----
header   = 'D3Dlike_Hmode_golden'   # HDF5 db name (no .h5)
n_equils = 20                        # draws to attempt
seed     = 12345                     # RNG seed for reproducible draws

# ---- perturbation / GPR settings ----
pad_psi   = 1e-4
n_ls, t_ls, j_ls = 0.5, 0.4, 0.25      # GPR length scales (ne, T, j)
frac_jphi = 0.10                        # flat fractional j_phi envelope
jBS_scale_range = [0.99, 1.01]          # bootstrap multiplicative spread
l_i_tolerance   = 0.05                   # l_i acceptance band (fraction)

# ---- bouquet backend options ----
# Reference per-draw diagnostics to the unperturbed jphi-linterp baseline
# (so a sigma=0 draw lands ~0 mm / ~0% from baseline) instead of recon's
# inverse-mode LCFS.
jphi_baseline = True

# ---- coil-drift / homotopy / in-spec (DIII-D +/-2% measurement spec) ----
# Everything is a FRACTION (decimal), never a percentage.
coil_drift      = 0.01                   # +/-1% hard coil-current bound
homotopy_passes = [(0.05, 0.10), (0.02, 0.05), (0.01, 0.01)]  # (F, VSC) limits
inspec_F_max    = 0.02                   # in-spec non-VSC F-coil drift
inspec_VSC_max  = 0.02                   # in-spec VSC (F9A/F9B) drift
vsc_soft_reg_weight = 1.0
p_thresh        = 0.05                   # pressure-match tolerance

# ---- p-file ion species ----
ion_N, ion_Z, ion_A = [6, 1, 1], [6, 1, 1], [12, 2, 2]

print(f"REGENERATE={REGENERATE}  n_equils={n_equils}  seed={seed}  header={header}")
# Out:
# REGENERATE=True  n_equils=20  seed=12345  header=D3Dlike_Hmode_golden

# %%
# [run-mode]
# When not regenerating, confirm the golden draws exist and report what they
# contain — including the TokaMaker-reconstructed baseline equilibrium.
if REGENERATE:
    print(f"REGENERATE=True -> reconstruct + generate {n_equils} draws into {header}.h5")
else:
    assert os.path.exists(header + '.h5'), (
        f"{header}.h5 not found. Set REGENERATE=True to build it, or place the "
        f"golden draws file next to this notebook.")
    import h5py
    with h5py.File(header + '.h5', 'r') as _hf:
        _bl = _hf['scan/0/_baseline']
        _ndraws = sum(1 for k in _hf['scan/0'] if k.isdigit())
        print(f"REGENERATE=False -> using existing {header}.h5")
        print(f"  stored draws             : {_ndraws}")
        print(f"  recon baseline equilib.  : "
              f"{'YES (baseline.eqdsk)' if 'baseline.eqdsk' in _bl else 'NO'}")
        print(f"  recon LCFS reference     : "
              f"{'present' if 'recon_lcfs_ref' in _bl else 'absent'}")
        if 'Ip_target' in _bl.attrs:
            print(f"  baseline Ip_target       : {_bl.attrs['Ip_target']/1e6:.3f} MA")
        if 'l_i_target' in _bl.attrs:
            print(f"  baseline l_i_target      : {float(_bl.attrs['l_i_target']):.4f}")
# Out:
# REGENERATE=True -> reconstruct + generate 20 draws into D3Dlike_Hmode_golden.h5

# %% [markdown]
# ## 3. Load baseline equilibrium + kinetic profiles

# %%
if REGENERATE:
    eqdsk = read_geqdsk(GEQ, cocos=1)
    psi_N = eqdsk.psi_N
    F0 = abs(eqdsk.R_center * eqdsk.B_center)   # |F0| for the solve (sign handled by file)

    pf = read_pfile(PF)
    if pf.ion_species is None:
        pf.set_ion_species(N=ion_N, Z=ion_Z, A=ion_A)
    pf.compute_quasineutrality()
    psi_pf, Zeff = pf.compute_zeff()

    # SI profiles on the equilibrium psi_N grid (for reconstruction)
    ne_SI = interp1d(psi_pf, pf.ne*1e20, fill_value='extrapolate')(psi_N)   # m^-3
    te_SI = interp1d(psi_pf, pf.te*1e3,  fill_value='extrapolate')(psi_N)   # eV
    ni_SI = interp1d(psi_pf, pf.ni*1e20, fill_value='extrapolate')(psi_N)
    ti_SI = interp1d(psi_pf, pf.ti*1e3,  fill_value='extrapolate')(psi_N)
    Zeff_eq = np.clip(interp1d(psi_pf, Zeff, fill_value='extrapolate')(psi_N), 1.0, None)

    print(f"Ip = {eqdsk.Ip:+.3e} A   Bt = {eqdsk.B_center:+.3f} T   F0 = {F0:.4f}")
    print(f"ne0 = {ne_SI[0]:.3e} m^-3   Te0 = {te_SI[0]:.0f} eV   Ti0 = {ti_SI[0]:.0f} eV")
# Out:
# Ip = +1.200e+06 A   Bt = -2.008 T   F0 = 3.3910
# ne0 = 5.500e+19 m^-3   Te0 = 2500 eV   Ti0 = 5000 eV

# %% [markdown]
# ## 4. Initialize TokaMaker (DIII-D mesh, weak coil reg toward zero)

# %%
if REGENERATE:
    myOFT = OFT_env(nthreads=int(os.environ.get('NTHREADS', '4')))
    mygs  = TokaMaker(myOFT)
    mp, ml, mr, cd, cnd = load_gs_mesh(MESH)
    mygs.setup_mesh(mp, ml, mr)
    mygs.setup_regions(cond_dict=cnd, coil_dict=cd)
    mygs.setup(order=3, F0=F0)
    mygs.settings.maxits = 800
    mygs.settings.pm = False
    mygs.update_settings()
    mygs.set_coil_vsc({'F9A': 1.0, 'F9B': -1.0})

    # Weak regularization toward zero -> free inverse solve finds the coil currents
    reg = [mygs.coil_reg_term({n: 1.0}, target=0.0, weight=1.0) for n in mygs.coil_sets]
    reg.append(mygs.coil_reg_term({'#VSC': 1.0}, target=0.0, weight=1e-2))
    mygs.set_coil_reg(reg_terms=reg)

    iso = np.column_stack([eqdsk.boundary_R, eqdsk.boundary_Z])
    isow = np.ones(len(iso)) * 200.0
    mygs.set_isoflux(iso, weights=isow)
    print(f"TokaMaker ready: {len(mp)} mesh pts, {len(mygs.coil_sets)} coil sets")
# Out:
# #----------------------------------------------
# Open FUSION Toolkit Initialized
# Development branch:    feat/jphi-linterp-Ip-cutcell-fix
# Revision id:           97436b2
# Parallelization Info:
#   Not compiled with MPI
#   # of OpenMP threads =    4
# Integer Precisions    =    4   8
# Float Precisions      =    4   8  16
# Complex Precisions    =    4   8
# LA backend            = native
# #----------------------------------------------
#
#
# **** Loading OFT surface mesh
#
# **** Generating surface grid level  1
#   Generating boundary domain linkage
#   Mesh statistics:
#     Area         =  1.574E+01
#     # of points  =    8910
#     # of edges   =   26567
#     # of cells   =   17658
#     # of boundary points =     160
#     # of boundary edges  =     160
#     # of boundary cells  =     160
#   Resolution statistics:
#     hmin =  8.702E-04
#     hrms =  4.833E-02
#     hmax =  1.540E-01
#   Surface grounded at vertex    1733
#
#
# **** Creating Lagrange FE space
# ...

# %% [markdown]
# ## 5. Reconstruct the baseline equilibrium

# %%
if REGENERATE:
    guess = create_power_flux_fun(len(psi_N), 1.5, 1.5)['y']
    result = reconstruct_equilibrium(
        mygs, eqdsk, ne_SI, te_SI, ni_SI, ti_SI, Zeff_eq, iso, isow, pad_psi,
        guess_jinductive=guess, n_k=5, psi_bridge=0.99, rescale_j_BS=False,
        shelf_psi_N=0.0, initialize_psi=True)

    Ip_target  = abs(eqdsk.Ip)
    # l_i target = recon equilibrium l_i from the current solved state
    # (NOT a hardcoded value).
    l_i_target = float(mygs.get_stats(lcfs_pad=pad_psi, li_normalization='std')['l_i'])
    print(f"l_i target = {l_i_target:.4f}   Ip target = {Ip_target/1e6:.3f} MA")
# Out:
#  >>> Matching input core j_phi with G-S solution
#
#  >>> Finding optimal j_phi scale factor
#
# --- Checking scale_j0 = 1.0000 ---
#    Input j_0:  1.3492e+06
#    Output j_0: 1.4127e+06
#    Mismatch:  4.499%
#
# --- Checking scale_j0 = 1.2000 ---
#    Input j_0:  1.6014e+06
#    Output j_0: 1.4564e+06
#    Mismatch:  9.958%
# --- Optimization Iteration 1 ---
#
# --- Checking scale_j0 = 1.0609 ---
#    Input j_0:  1.4260e+06
#    Output j_0: 1.4273e+06
#    Mismatch:  0.090%
# Converged! Optimal scale factor: 1.0609
#
#  >>> Iterating on H-mode equilibrium solution
# [classify] H_mode — geqdsk peak at psi_N=0.9609 (0.7908 MA/m²), Sauter peak at psi_N=0.9609 (0.5610 MA/m²), height ratio=0.71, psiN offset=0.0000
# [fit] ind_scale=1.025253  bs_scale=1.000000  li_proxy=0.898833  (target=0.898833)
# [spline_check] max |d²j_ind/dpsi²| = 0.0665 MA/m²/psiN² at index 249 (psi_N=0.97266)
# [li match] target=0.840953
# [li match] iter 0: ind_factor=1.000000  li=0.869409  err=0.028456
# ...

# %% [markdown]
# ### 5a. Verify the reconstruction against the baseline g-file

# %%
if REGENERATE:
    plot_tokamaker_comparison(mygs, {GEQ: result}, plot_idx=0)
    plt.show()
# Out:
# --- Summary for D3Dlike_Hmode_baseline.geqdsk ---
#   bs_factor_final : 1.000000
#   li(1) achieved  : 0.840548
#   j_phi RMS error : 25189.21 A/m^2  (0.0252 MA/m^2)
#   eqdsk Ip        : 1200299 A
#   TokaMaker Ip    : 1200618 A  (+0.027%)
#   Boundary dev.   : max=9.16 mm  RMS=2.75 mm

# %% [markdown]
# ## 6. Build synthetic IDA-like uncertainty envelopes
#
# `synthetic_ida_sigma(psi_N, channel)` returns the *fractional* 1σ envelope on a
# sine basis calibrated to a DIII-D IDA-like shape (flat-ish core, edge
# enhancement; Te/Ti carry a mid-radius bump).  Multiply by each profile to get
# the absolute σ.  The j_phi envelope stays a flat 10 % (a representative
# workflow).

# %%
if REGENERATE:
    # kinetic-grid profiles (p-file grid) for the bouquet sampler
    ne_kin = pf.ne*1e20; te_kin = pf.te*1e3; ni_kin = pf.ni*1e20; ti_kin = pf.ti*1e3

    sig_ne = synthetic_ida_sigma(psi_pf, 'ne') * ne_kin
    sig_te = synthetic_ida_sigma(psi_pf, 'te') * te_kin
    sig_ni = synthetic_ida_sigma(psi_pf, 'ni') * ni_kin
    sig_ti = synthetic_ida_sigma(psi_pf, 'ti') * ti_kin
    sigma_jphi = frac_jphi * np.abs(result['j_phi_fit'])

    # quick look at the fractional envelopes
    fig, ax = plt.subplots(figsize=(7, 4))
    for ch, col in [('ne', 'tab:blue'), ('te', 'tab:red'), ('ti', 'tab:green')]:
        ax.plot(psi_pf, synthetic_ida_sigma(psi_pf, ch)*100, color=col, lw=2, label=ch)
    ax.set_xlabel(r'$\psi_N$'); ax.set_ylabel('fractional $\sigma$ [%]')
    ax.set_xlim(0, 1); ax.grid(alpha=0.3); ax.legend(); ax.set_title('Synthetic IDA-like uncertainties')
    plt.show()
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# <>:15: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/wz/x_qd5n8d62s0qj0_kcyyqf780000gn/T/ipykernel_38505/2115573009.py:15: SyntaxWarning: invalid escape sequence '\s'
#   ax.set_xlabel(r'$\psi_N$'); ax.set_ylabel('fractional $\sigma$ [%]')

# %% [markdown]
# ## 7. Generate the perturbed bouquet
#
# `generate_bouquet` draws GPR-perturbed kinetic + j_phi profiles, recomputes the
# bootstrap current, conditions each draw's `l_i` into the acceptance band, then
# runs a hard-bound homotopy (loose → strict) on the PF coils, recording per-draw
# boundary deviation, `l_i`, coil drift, and in-spec status into the HDF5
# database.

# %%
if REGENERATE:
    # fresh database
    if os.path.exists(header + '.h5'):
        os.remove(header + '.h5')
    initialize_equilibrium_database(header)

    with open(GEQ, 'rb') as fh: baseline_eqdsk_raw = fh.read()
    with open(PF,  'rb') as fh: pfile_raw = fh.read()

    # restore the recon isoflux targets before sampling
    mygs.set_isoflux(result['isoflux_pts'], weights=result['weights'])

    diagnostics = generate_bouquet(
        mygs, psi_N, n_equils, header,
        result['j_phi_fit'],
        ne_kin, te_kin, ni_kin, ti_kin,
        sig_ne, sig_te, sig_ni, sig_ti, sigma_jphi,
        n_ls, t_ls, j_ls,
        Ip_target, l_i_target, Zeff_eq,
        input_jinductive=result['j_inductive_fit'],
        l_i_tolerance=l_i_tolerance,
        psi_pad=pad_psi,
        constrain_sawteeth=False,
        recalculate_j_BS=True,
        jBS_scale_range=jBS_scale_range,
        pfile_bytes=pfile_raw,
        baseline_eqdsk_bytes=baseline_eqdsk_raw,
        baseline_pfile_bytes=pfile_raw,
        diagnostic_plots=False,
        scan_val=0,
        psi_N_kinetic=psi_pf,
        coil_drift=coil_drift,
        homotopy_passes=homotopy_passes,
        inspec_F_max=inspec_F_max,
        inspec_VSC_max=inspec_VSC_max,
        p_thresh=p_thresh,
        vsc_soft_reg_weight=vsc_soft_reg_weight,
        save_truncate_eq=True,   # drop the held-then-snapped separatrix node -> smooth edge j_phi
        jphi_baseline=jphi_baseline,   # diagnostics reference the jphi-linterp baseline
        seed=seed,                     # reproducible draws (seeds the RNG inside)
    )
    print(f"\n{len(diagnostics)} equilibria archived in {header}.h5")
# Out:
# /var/folders/wz/x_qd5n8d62s0qj0_kcyyqf780000gn/T/ipykernel_38505/2977400313.py:11: DeprecationWarning: `set_isoflux()` is deprecated, use `set_isoflux_constraints()` instead. This function will be removed in a future version.
#   mygs.set_isoflux(result['isoflux_pts'], weights=result['weights'])
#   [jphi-baseline] unperturbed jphi-linterp baseline solved: l_i(1)=0.84064 Ip=1200615; per-draw boundary/l_i now reference THIS baseline
#   [bnd-diag] using recon LCFS reference: 9226 pts (caller-supplied)
#   [warmstart] snapshot of RECON state captured (FULL eq object via copy_eq, 256 isoflux pts) -- every draw will restore from this baseline, not propagate prior draws' state
# Saving gEQDSK: /var/folders/wz/x_qd5n8d62s0qj0_kcyyqf780000gn/T/tmpw2xn0ra7.geqdsk
# ...

# %% [markdown]
# ## 8. Visualize the bouquet

# %%
plot_bouquet(header, scan_value=0, mode='all')
plt.show()

# %%
figs = plot_traces(header, scan_value='all')
plt.show()

# %% [markdown]
# ### 8a. Per-coil current drift across the bouquet

# %%
plot_coil_currents(header, scan_val=0)
plt.show()

# %% [markdown]
# ### 8b. Perturbed g-file + p-file overlays

# %%
plot_geqdsk_bouquet(h5path=f"{header}.h5", x_coord="rho")
plt.show()
# Out:
# /Users/danielburgess/Desktop/plasma/bouquet_coil_bounds/bouquet/plotting.py:1245: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
plot_pfile_bouquet(h5path=f"{header}.h5", scan_val=0, x_coord="psi_N")
plt.show()

# %% [markdown]
# ### 8c. Per-draw summary (yield, in-spec, l_i / boundary spread)
#
# Reads the HDF5 attrs written by `generate_bouquet` and prints the realized
# distribution — the numbers the golden test will lock in.

# %%
import h5py
with h5py.File(f"{header}.h5", 'r') as hf:
    p = hf['scan/0']
    counts = sorted(int(k) for k in p.keys() if k.isdigit())
    rows = []
    for c in counts:
        g = p[str(c)]
        rows.append(dict(
            i=c,
            in_spec=bool(g.attrs.get('in_spec', False)),
            homotopy_pass=int(g.attrs.get('homotopy_pass', -1)),
            max_F=float(g.attrs.get('max_F_drift_pct', np.nan)),
            max_VSC=float(g.attrs.get('max_VSC_drift_pct', np.nan)),
        ))
n = len(rows); n_spec = sum(r['in_spec'] for r in rows)
print(f"archived draws : {n} / {n_equils}")
print(f"in-spec        : {n_spec} / {n}")
print(f"max non-VSC F drift : med {np.nanmedian([r['max_F'] for r in rows]):.2f}%"
      f"  max {np.nanmax([r['max_F'] for r in rows]):.2f}%")
print(f"max VSC drift       : med {np.nanmedian([r['max_VSC'] for r in rows]):.2f}%"
      f"  max {np.nanmax([r['max_VSC'] for r in rows]):.2f}%")
# Out:
# archived draws : 20 / 20
# in-spec        : 10 / 20
# max non-VSC F drift : med 0.79%  max 1.97%
# max VSC drift       : med 2.18%  max 5.46%

# %% [markdown]
# ### 8d. In-spec / out-of-spec coil-current validation
#
# In-spec / out-of-spec diagnostics.  **Panel set 1** (per-draw bars, green = in-spec,
# red = out-of-spec): boundary RMS/max, max non-VSC F-coil drift, and max VSC
# (F9A/F9B) drift, each vs the ±2 % spec line.  **Panel set 2** (per-coil): the
# drift of every PF coil across the bouquet, separated into non-VSC F-coils, the
# VSC pair, and the E-coils, so out-of-spec coils are identifiable individually.
#
# Drift = (I_draw − I_baseline) / |I_baseline| × 100 %.

# %%
# [coil-inspec-diagnostics]
# Per-draw in-spec diagnostics from the H5 attrs written by generate_bouquet.
import h5py
import numpy as np
import matplotlib.pyplot as plt
from bouquet import GEQDSKEquilibrium

def _p2s(p, a, b):
    ap = p - a; ab = b - a
    t = np.clip(np.dot(ap, ab) / max(np.dot(ab, ab), 1e-30), 0, 1)
    return np.linalg.norm(p - (a + t * ab))
def _p2c(p, c):
    n = len(c); return min(_p2s(p, c[i], c[(i+1) % n]) for i in range(n))
def _curve_rms_max_mm(c1, c2):
    d1 = np.array([_p2c(p, c2) for p in c1]); d2 = np.array([_p2c(p, c1) for p in c2])
    return (0.5*(np.sqrt(np.mean(d1**2))+np.sqrt(np.mean(d2**2)))*1e3,
            float(np.max(np.concatenate([d1, d2])))*1e3)

h5file = f"{header}.h5"; SCAN_KEY = '0'
with h5py.File(h5file, 'r') as hf:
    parent = hf[f'scan/{SCAN_KEY}']; bl = parent['_baseline']
    bl_eq = GEQDSKEquilibrium.from_bytes(bytes(np.array(bl['baseline.eqdsk']).tobytes()), cocos=1)
    ref_xy = np.column_stack([bl_eq.boundary_R, bl_eq.boundary_Z])
    counts = sorted(int(k) for k in parent.keys() if k.isdigit())
    # in-spec thresholds are stored per-draw; read from the first draw (fallback 2%)
    _a0 = parent[str(counts[0])].attrs if counts else {}
    inspec_F   = float(_a0.get('inspec_F_max',   0.02))
    inspec_VSC = float(_a0.get('inspec_VSC_max', 0.02))
    bnd_rms = np.full(len(counts), np.nan); bnd_max = np.full(len(counts), np.nan)
    pass_idx = np.full(len(counts), -1, int)
    max_F = np.full(len(counts), np.nan); max_VSC = np.full(len(counts), np.nan)
    in_spec = np.zeros(len(counts), bool)
    for i, c in enumerate(counts):
        g = parent[str(c)]
        ek = next((kk for kk in g.keys() if kk.endswith('.eqdsk')), None)
        if ek is not None:
            eq = GEQDSKEquilibrium.from_bytes(bytes(np.array(g[ek]).tobytes()), cocos=1)
            bnd_rms[i], bnd_max[i] = _curve_rms_max_mm(
                ref_xy, np.column_stack([eq.boundary_R, eq.boundary_Z]))
        pass_idx[i] = int(g.attrs.get('homotopy_pass', -1))
        max_F[i]   = float(g.attrs.get('max_F_drift_pct', np.nan))
        max_VSC[i] = float(g.attrs.get('max_VSC_drift_pct', np.nan))
        in_spec[i] = bool(g.attrs.get('in_spec', False))

print(f"Equilibria stored: {len(counts)}")
print(f"In-spec criterion: max F-drift <= {inspec_F*100:.1f}%, max VSC <= {inspec_VSC*100:.1f}%")
print(f"In-spec count:     {in_spec.sum()}/{len(counts)} "
      f"({100*in_spec.sum()/max(len(counts),1):.0f}%)")
# homotopy-pass breakdown (0=Pass1 loose, 1=Pass2 mid, 2=Pass3 strict)
pass_labels = ['Pass 1 (loose)', 'Pass 2 (mid)', 'Pass 3 (strict)']
for _p in range(3):
    _np = int(np.sum(pass_idx == _p))
    if _np:
        print(f"  reached {pass_labels[_p]:<16s}: {_np}/{len(counts)}")

# baseline's OWN boundary residual vs its eqdsk, for reference on the bnd panel
# (computed, not hardcoded -- the baseline's own recon-residual line).  The
# recon LCFS trace is stored as 'recon_lcfs_ref' on the baseline group.
recon_resid = None
with h5py.File(h5file, 'r') as hf:
    _bl = hf[f'scan/{SCAN_KEY}/_baseline']
    if 'recon_lcfs_ref' in _bl:
        _rl = np.array(_bl['recon_lcfs_ref'])
        if _rl.ndim == 2 and _rl.shape[1] == 2:
            recon_resid = _curve_rms_max_mm(ref_xy, _rl)[0]

x = np.arange(len(counts)); colors = ['tab:green' if s else 'tab:red' for s in in_spec]
fig, axs = plt.subplots(3, 1, figsize=(11, 9), sharex=True)
w = 0.4
axs[0].bar(x - w/2, bnd_rms, w, color=colors, edgecolor='k', alpha=0.85, label='RMS')
axs[0].bar(x + w/2, bnd_max, w, color=colors, edgecolor='k', alpha=0.4, label='Max')
if recon_resid is not None:
    axs[0].axhline(recon_resid, ls='--', color='gray', lw=1.0,
                   label=f"baseline recon residual ({recon_resid:.2f} mm)")
axs[0].set_ylabel('Boundary deviation [mm]')
axs[0].set_title('Per-draw diagnostics (green = in_spec, red = out_of_spec)')
axs[0].legend(fontsize=8); axs[0].grid(ls=':', alpha=0.4, axis='y')
axs[1].bar(x, max_F, color=colors, edgecolor='k', alpha=0.85)
axs[1].axhline(inspec_F*100, ls='--', color='k', lw=1.2, label=f'spec ({inspec_F*100:.1f}%)')
axs[1].set_ylabel('max non-VSC F-coil drift [%]'); axs[1].legend(); axs[1].grid(ls=':', alpha=0.4, axis='y')
axs[2].bar(x, max_VSC, color=colors, edgecolor='k', alpha=0.85)
axs[2].axhline(inspec_VSC*100, ls='--', color='k', lw=1.2, label=f'spec ({inspec_VSC*100:.1f}%)')
axs[2].set_ylabel('max VSC (F9A/F9B) drift [%]'); axs[2].set_xlabel('Perturbed equilibrium index')
axs[2].legend(); axs[2].grid(ls=':', alpha=0.4, axis='y')
plt.tight_layout(); plt.show()
# Out:
# Equilibria stored: 20
# In-spec criterion: max F-drift <= 2.0%, max VSC <= 2.0%
# In-spec count:     10/20 (50%)
#   reached Pass 1 (loose)  : 6/20
#   reached Pass 2 (mid)    : 14/20

# %%
# [coil-inspec-diagnostics]
# Per-coil drift plot, separated into three classes:
#   * Non-VSC F-coils (F1-F8 A/B): rainbow colors, spec line at +/-inspec_F_max
#   * VSC pair (F9A/F9B):          black/grey, spec line at +/-inspec_VSC_max
#   * E-coils (ECOILA, ECOILB):    NOT in in_spec criterion (bounded by
#                                  coil_drift_floor_A absolute, so their % drift
#                                  can exceed 2% on small baselines -- a floor
#                                  reading, not a spec violation).
# In-spec draws shaded green, out-of-spec red.  Drift = (I_draw - I_baseline) /
# |I_baseline| * 100, NaN if |I_baseline| < 1A.
import h5py, json as _json
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

NON_VSC_F = ['F1A','F2A','F3A','F4A','F5A','F6A','F7A','F8A',
             'F1B','F2B','F3B','F4B','F5B','F6B','F7B','F8B']
VSC_PAIR = ['F9A', 'F9B']; E_COILS = ['ECOILA', 'ECOILB']
MARKERS = ['o','s','D','^','v','<','>','p']; CMAP = plt.get_cmap('gist_rainbow')
F_style = {n: {'color': CMAP(i/max(len(NON_VSC_F)-1,1)), 'marker': MARKERS[i % len(MARKERS)]}
           for i, n in enumerate(NON_VSC_F)}
VSC_style = {'F9A': {'color':'black','marker':'*'}, 'F9B': {'color':'dimgray','marker':'*'}}
E_style = {'ECOILA': {'color':'tab:purple','marker':'X','ls':'--'},
           'ECOILB': {'color':'tab:olive','marker':'X','ls':'--'}}

h5file = f"{header}.h5"
records = []; inspec_F = inspec_VSC = None
with h5py.File(h5file, 'r') as hf:
    scan_keys = sorted(hf['scan'].keys()) if 'scan' in hf else []
    for sk in scan_keys:
        parent = hf[f'scan/{sk}']; bl = parent['_baseline']
        if 'coil_currents [A]' not in bl or 'coil_names' not in bl:
            print(f"  scan={sk}: no baseline coil_currents stored, skipping"); continue
        ref_names = [s.decode() if isinstance(s, bytes) else s for s in np.array(bl['coil_names'])]
        ref_dict = dict(zip(ref_names, np.array(bl['coil_currents [A]'])))
        _draws = sorted(int(k) for k in parent.keys() if k.isdigit())
        if inspec_F is None and _draws:            # thresholds stored per-draw
            _a = parent[str(_draws[0])].attrs
            inspec_F = float(_a.get('inspec_F_max', 0.02))
            inspec_VSC = float(_a.get('inspec_VSC_max', 0.02))
        for c in _draws:
            g = parent[str(c)]
            if 'coil_currents [A]' not in g: continue
            d_names = _json.loads(g.attrs.get('coil_names', '[]'))
            d_dict = dict(zip(d_names, np.array(g['coil_currents [A]'])))
            records.append((sk, c, ref_dict, d_dict, bool(g.attrs.get('in_spec', False))))

def drift_pct(d, ref, coil):
    r = ref.get(coil, np.nan); v = d.get(coil, np.nan)
    return 100.0*(v-r)/abs(r) if (np.isfinite(r) and np.isfinite(v) and abs(r) > 1.0) else np.nan

n_eq = len(records)
print(f"Loaded {n_eq} equilibria across {len(scan_keys)} scan(s).")
print(f"In-spec criterion: max non-VSC F-coil <= {inspec_F*100:.1f}%, max VSC <= {inspec_VSC*100:.1f}%")
print("NOTE: E-coils are bounded by coil_drift_floor_A absolute (default 50A); on")
print("      small-baseline E-coils this can be ~5-10% -- a floor reading, not a violation.")
if n_eq == 0:
    print("No data to plot.")
else:
    x = np.arange(n_eq); in_spec_arr = np.array([r[4] for r in records])
    fig, (ax_F, ax_VSC, ax_E) = plt.subplots(3, 1, figsize=(13, 10), sharex=True)
    legend_F = []
    for coil in NON_VSC_F:
        st = F_style[coil]
        ys = [drift_pct(dr, ref, coil) for (_, _, ref, dr, _) in records]
        ax_F.plot(x, ys, '-', color=st['color'], marker=st['marker'], ms=5, alpha=0.85, lw=1.0)
        legend_F.append(Line2D([0],[0], color=st['color'], marker=st['marker'], ms=6, lw=1.5, label=coil))
    ax_F.axhline(+inspec_F*100, color='k', ls='--', lw=1.2); ax_F.axhline(-inspec_F*100, color='k', ls='--', lw=1.2)
    ax_F.axhline(0, color='k', lw=0.8); ax_F.set_ylabel('Non-VSC F-coil drift [%]')
    ax_F.set_title(f'Per-coil drift, {n_eq} equilibria (green = in_spec, red = out_of_spec)')
    ax_F.grid(ls=':', alpha=0.4, axis='y')
    legend_VSC = []
    for coil in VSC_PAIR:
        st = VSC_style[coil]
        ys = [drift_pct(dr, ref, coil) for (_, _, ref, dr, _) in records]
        ax_VSC.plot(x, ys, '-', color=st['color'], marker=st['marker'], ms=7, alpha=0.85, lw=1.2)
        legend_VSC.append(Line2D([0],[0], color=st['color'], marker=st['marker'], ms=8, lw=1.5, label=coil))
    ax_VSC.axhline(+inspec_VSC*100, color='k', ls='--', lw=1.2); ax_VSC.axhline(-inspec_VSC*100, color='k', ls='--', lw=1.2)
    ax_VSC.axhline(0, color='k', lw=0.8); ax_VSC.set_ylabel('VSC pair drift [%]'); ax_VSC.grid(ls=':', alpha=0.4, axis='y')
    legend_E = []
    for coil in E_COILS:
        st = E_style[coil]
        ys = [drift_pct(dr, ref, coil) for (_, _, ref, dr, _) in records]
        ax_E.plot(x, ys, ls=st['ls'], color=st['color'], marker=st['marker'], ms=6, alpha=0.85, lw=1.2)
        legend_E.append(Line2D([0],[0], color=st['color'], ls=st['ls'], marker=st['marker'], ms=7, lw=1.5, label=coil))
    ax_E.axhline(0, color='k', lw=0.8); ax_E.set_ylabel('E-coil drift [%]')
    ax_E.set_xlabel('Perturbed equilibrium index'); ax_E.grid(ls=':', alpha=0.4, axis='y')
    # in-spec green/red shading across all panels
    for ax in (ax_F, ax_VSC, ax_E):
        for i, ok in enumerate(in_spec_arr):
            ax.axvspan(i-0.4, i+0.4, color=('tab:green' if ok else 'tab:red'), alpha=0.10 if ok else 0.05)
    ax_F.legend(handles=legend_F, loc='center left', bbox_to_anchor=(1.01,0.5), fontsize=7, title='F1-F8 A/B')
    ax_VSC.legend(handles=legend_VSC, loc='center left', bbox_to_anchor=(1.01,0.5), fontsize=8, title='VSC')
    ax_E.legend(handles=legend_E, loc='center left', bbox_to_anchor=(1.01,0.5), fontsize=8, title='E-coils (50A floor)')
    plt.tight_layout(rect=[0, 0, 0.90, 1]); plt.show()

    def _drift_stats(coils):
        ds = [abs(v) for coil in coils for (_,_,ref,dr,_) in records
              if np.isfinite(v := drift_pct(dr, ref, coil))]
        return (np.median(ds), np.percentile(ds,95), max(ds)) if ds else None
    print(f"\nDrift summary by coil class (|drift| %):")
    print(f'  {"class":<22s}  {"median":>7s}  {"95th":>7s}  {"max":>7s}')
    for label, coils in [('Non-VSC F-coils', NON_VSC_F), ('VSC pair (F9A/F9B)', VSC_PAIR), ('E-coils', E_COILS)]:
        s = _drift_stats(coils)
        if s: print(f'  {label:<22s}  {s[0]:>6.2f}%  {s[1]:>6.2f}%  {s[2]:>6.2f}%')
# Out:
# Loaded 20 equilibria across 1 scan(s).
# In-spec criterion: max non-VSC F-coil <= 2.0%, max VSC <= 2.0%
# NOTE: E-coils are bounded by coil_drift_floor_A absolute (default 50A); on
#       small-baseline E-coils this can be ~5-10% -- a floor reading, not a violation.
# Drift summary by coil class (|drift| %):
#   class                    median     95th      max
#   Non-VSC F-coils           0.07%    0.81%    1.97%
#   VSC pair (F9A/F9B)        2.04%    5.20%    5.46%
#   E-coils                   1.45%    3.49%    4.02%

# %% [markdown]
# ## 9. Filter the bouquet to the deliverable subset
#
# Not every generated draw is usable. The coil-current spec is the **binding constraint**: a draw whose F-coils or the F9A/F9B vertical-stability pair drift past ±2 % could not be reproduced on DIII-D within its current-measurement uncertainty. Some draws also push the LCFS further than a particular study allows.
#
# Filtering is a **postprocessing** step and is **non-destructive**: each filter tags every draw pass/fail (writing `passes_coil_filter` / `passes_boundary_filter` and a derived `selected` flag) but never deletes data. So you can:
#
# 1. **see** the in-spec / out-of-spec distribution before cutting,
# 2. **re-cut** at a different threshold with no physics re-run,
# 3. **re-plot** keeping only the survivors, and
# 4. **export** a pruned copy for downstream analysis.

# %%
# [bouquet-filtering]
# Coil-current spec filter — the binding constraint.
# With no thresholds it uses the inspec_F_max / inspec_VSC_max recorded at
# generation time (here ±2 %), so it reproduces the in-loop in_spec
# decision exactly.  Override F_max_pct / VSC_max_pct to re-cut at a
# different tolerance WITHOUT re-running any physics.
from bouquet import (filter_coil_currents, filter_boundaries,
                     select_indices, export_filtered)

coil_summary, _ = filter_coil_currents(header, scan_value=0)
cs = coil_summary[0]
print(f"coil-current in-spec: {cs['n_pass']}/{cs['n_total']} "
      f"({cs['n_fail']} out-of-spec)")
# Out:
# coil-current in-spec: 10/20 (10 out-of-spec)

# %%
# [bouquet-filtering]
# Boundary-deviation filter.  Called with NO threshold first => diagnostic
# only: it shows the LCFS RMS/max distribution and writes nothing, so you
# can read a sensible cut off the plot.  Re-call with rms_max_mm=... (and/or
# max_max_mm=...) to actually mark draws and fold them into `selected`.
bnd_summary, _ = filter_boundaries(header, scan_value=0)
rs = bnd_summary[0]['rms_stats']
print(f"boundary RMS dev [mm]: median {rs['median']:.2f}  "
      f"95th {rs['p95']:.2f}  max {rs['max']:.2f}")
# e.g. to also cut on the boundary, uncomment:
# filter_boundaries(header, scan_value=0, rms_max_mm=5.0)
# Out:
# boundary RMS dev [mm]: median 2.50  95th 5.13  max 5.14

# %%
# [bouquet-filtering]
# What survived?  `selected` is the AND of every applied filter.
sel = select_indices(header, scan_value=0, selection='selected')
exc = select_indices(header, scan_value=0, selection='excluded')
print(f"selected (deliverable): {len(sel)} draws  {sel}")
print(f"excluded (out-of-spec): {len(exc)} draws  {exc}")

# Re-plot the bouquet keeping ONLY the in-spec family (selection='all'
# is the default and shows everything; 'excluded' shows just the cuts).
plot_bouquet(header, scan_value=0, mode='boundary', selection='selected');
# Out:
# selected (deliverable): 10 draws  [0, 4, 5, 6, 7, 8, 9, 11, 12, 15]
# excluded (out-of-spec): 10 draws  [1, 2, 3, 10, 13, 14, 16, 17, 18, 19]

# %%
# [bouquet-filtering]
# Materialise a pruned copy with only the selected draws.  The baseline
# is preserved and the original h5 is left untouched; this pruned file is
# the family you'd hand to downstream analysis.
kept = export_filtered(header, f"{header}_selected.h5",
                       scan_value=0, selection='selected', overwrite=True)
print(f"wrote {header}_selected.h5  ({kept} draws kept)")
# Out:
# wrote D3Dlike_Hmode_golden_selected.h5  (10 draws kept)
